# %%
import pandas as pd
import numpy as np

import sklearn 

from numpy import mean
from numpy import std

from sklearn.preprocessing import StandardScaler

from sklearn import linear_model
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedKFold

from sklearn.metrics import make_scorer

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 100)

# %%
# Basic Dummified Dataset for Linear Models
base = pd.read_csv('../Data/BaseData.csv')
base.shape
# Out:
# (2580, 298)

# %%
#base

# %%
# Use cross-validation to evaluate model performance

def evaluate_model(model, X, y):
    
    # define the evaluation procedure
    cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=1)
    
    # evaluate the model and collect the results
    scores = cross_validate(model, X, y, cv=cv, n_jobs=-1) 
    
    df = pd.DataFrame(scores)
    
    return df

# %%
X = base['GrLivArea'].values.reshape(-1,1)
y = base.SalePrice.values.reshape(-1,1)
simple1 = linear_model.LinearRegression()
SLR1 = evaluate_model(simple1, X, y)[['test_score']]
SLR1 = SLR1.rename(columns={'test_score':'SLR (Area)'})
SLR1
# Out:
#     SLR (Area)
# 0     0.492545
# 1     0.500684
# 2     0.530382
# 3     0.553000
# 4     0.509211
# 5     0.503816
# 6     0.569944
# 7     0.515928
# 8     0.493042
# 9     0.505414
# 10    0.557953
# 11    0.480105
# 12    0.428189
# 13    0.565351
# 14    0.525359

# %%
X = base['OverallQual'].values.reshape(-1,1)
y = base.SalePrice.values.reshape(-1,1)
simple2 = linear_model.LinearRegression()
SLR2 = evaluate_model(simple2, X, y)[['test_score']]
SLR2 = SLR2.rename(columns={'test_score':'SLR (Quality)'})
SLR2
# Out:
#     SLR (Quality)
# 0        0.601363
# 1        0.604992
# 2        0.631919
# 3        0.612772
# 4        0.664951
# 5        0.620319
# 6        0.654626
# 7        0.612257
# 8        0.645844
# 9        0.592861
# 10       0.636823
# 11       0.646617
# 12       0.582898
# 13       0.628856
# 14       0.607640

# %%
X = base[['GrLivArea','OverallQual']].values
y = base.SalePrice.values.reshape(-1,1)
mlr = linear_model.LinearRegression()
MLR = evaluate_model(mlr, X, y)[['test_score']]
MLR = MLR.rename(columns={'test_score':'MLR (Area & Quality)'})
MLR
# Out:
#     MLR (Area & Quality)
# 0               0.721532
# 1               0.714287
# 2               0.736684
# 3               0.755845
# 4               0.751330
# 5               0.724462
# 6               0.782182
# 7               0.724543
# 8               0.747638
# 9               0.708893
# 10              0.764368
# 11              0.720255
# 12              0.654818
# 13              0.766435
# 14              0.745547

# %%
X = base.drop(['SalePrice'], axis=1).values
y = base.SalePrice.values

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# list of penalized regression models to evaluate

def get_models():
    models = dict()
    models['ridge'] = Ridge() 
    models['lasso'] = Lasso() 
    models['elastic_net'] = ElasticNet()
    return models

# %%
models = get_models()

# %%
#Create List of Dictionaries to evalute models

dfs = list()

for name, model in models.items():
    
    # evaluate the model
    df = evaluate_model(model, X, y)
    dfs.append(df)

# %%
#dfs

# %%
ridge_df = dfs[0][['test_score']]
ridge_df = ridge_df.rename(columns = {'test_score':'Ridge'})
ridge_df
# Out:
#        Ridge
# 0   0.906132
# 1   0.858186
# 2   0.776873
# 3   0.921208
# 4   0.943573
# 5   0.916243
# 6   0.883911
# 7   0.924162
# 8   0.926505
# 9   0.867633
# 10  0.916545
# 11  0.907745
# 12  0.804888
# 13  0.911361
# 14  0.921205

# %%
lasso_df = dfs[1][['test_score']]
lasso_df = lasso_df.rename(columns = {'test_score':'Lasso'})
lasso_df
# Out:
#        Lasso
# 0   0.910384
# 1   0.858097
# 2   0.776695
# 3   0.921014
# 4   0.943476
# 5   0.913753
# 6   0.883419
# 7   0.925780
# 8   0.926305
# 9   0.867655
# 10  0.916492
# 11  0.907447
# 12  0.804559
# 13  0.914910
# 14  0.921261

# %%
elastic_df = dfs[2][['test_score']]
elastic_df = elastic_df.rename(columns = {'test_score':'ElasticNet'})
elastic_df
# Out:
#     ElasticNet
# 0     0.896418
# 1     0.846425
# 2     0.853683
# 3     0.892887
# 4     0.922612
# 5     0.908357
# 6     0.880169
# 7     0.904719
# 8     0.905795
# 9     0.848192
# 10    0.907414
# 11    0.883031
# 12    0.829967
# 13    0.896447
# 14    0.903938

# %%
ordinal = pd.read_csv('../Data/BaseOrdinal.csv')
ordinal.shape
# Out:
# (2580, 81)

# %%
ordinal.head(2)
# Out:
#    Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 0           0          3          3         3         3          3
# 1           1          4          3         4         3          3
#
#    KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  GarageCond  \
# 0            3           8            4             1           3           3
# 1            4           8            0             3           3           3
#
#    PoolQC  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0       0       5.0     1.0    1.0       3.0          3.0        0.0
# 1       0       5.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0        0.0        0.0          21.0         2.0         2.0       0.0
# 1        4.0        0.0           7.0         2.0         2.0       4.0
#
#    HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0         2.0        1.0       0.0         13.0         14.0         2.0
# 1         2.0        1.0       0.0          6.0          6.0         1.0
#
#    Foundation  BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  CentralAir  \
# 0         1.0           3.0           5.0           6.0      1.0         1.0
# 1         1.0           2.0           2.0           0.0      1.0         1.0
#
#    Electrical  GarageType  PavedDrive  Fence  MiscFeature  SaleType  \
# 0         3.0         5.0         2.0    4.0          1.0       9.0
# 1         3.0         1.0         2.0    4.0          1.0       9.0
#
#    SaleCondition  MSSubClass  MoSold  YrSold  GrLivArea  SalePrice  LotArea  \
# 0            4.0         6.0     5.0     4.0        856     126000     7890
# 1            4.0         0.0     4.0     3.0       1049     139500     4235
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  1stFlrSF  2ndFlrSF  \
# 0            6            6       1939          1950       856         0
# 1            5            5       1984          1984      1049         0
#
#    LowQualFinSF  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         1         0             2             1             4
# 1             0         2         0             2             1             5
#
#    Fireplaces  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0           1           0            0              0          0          166
# 1           0           0          105              0          0            0
#
#    PoolArea  MiscVal  LotFrontage  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0         0        0    68.516053         0.0       238.0         0.0
# 1         0        0    42.000000       149.0       552.0       393.0
#
#    BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath  GarageYrBlt  \
# 0      618.0        856.0           1.0           0.0       1939.0
# 1      104.0       1049.0           1.0           0.0       1984.0
#
#    GarageCars  GarageArea
# 0         2.0       399.0
# 1         1.0       266.0

# %%
ordinal = ordinal.drop(['Unnamed: 0'], axis=1)
ordinal.shape
# Out:
# (2580, 80)

# %%
X = ordinal.drop(['SalePrice'], axis=1)
y = ordinal.SalePrice

rf = RandomForestRegressor(bootstrap=True) 

RF = evaluate_model(rf, X, y)[['test_score']]
RF = RF.rename(columns={'test_score':'Random Forest'})
RF
# Out:
#     Random Forest
# 0        0.897587
# 1        0.856902
# 2        0.898612
# 3        0.879042
# 4        0.919555
# 5        0.897254
# 6        0.906944
# 7        0.893468
# 8        0.913180
# 9        0.847973
# 10       0.913801
# 11       0.884819
# 12       0.823639
# 13       0.906415
# 14       0.909470

# %%
def get_models_2():
    models = dict()
    models['gradient boost'] = GradientBoostingRegressor()
    models['Xtreme GB'] = XGBRegressor()
    models['CatBoost'] = CatBoostRegressor(verbose=False)
    return models

# %%
models2 = get_models_2()

# %%
#Create List of Dictionaries to evalute models

dfs2 = list()

for name, model in models2.items():
    
    # evaluate the model
    df = evaluate_model(model, X, y)
    dfs2.append(df)

# %%
#dfs2

# %%
gb = dfs2[0][['test_score']]
gb = gb.rename(columns = {'test_score':'Gradient Boost'})
gb
# Out:
#     Gradient Boost
# 0         0.914769
# 1         0.828986
# 2         0.919118
# 3         0.905515
# 4         0.935739
# 5         0.909002
# 6         0.925711
# 7         0.911508
# 8         0.929292
# 9         0.838481
# 10        0.935408
# 11        0.908924
# 12        0.817532
# 13        0.916969
# 14        0.922299

# %%
xgb = dfs2[1][['test_score']]
xgb = xgb.rename(columns = {'test_score':'XGB'})
xgb
# Out:
#          XGB
# 0   0.904162
# 1   0.829442
# 2   0.913540
# 3   0.890408
# 4   0.922078
# 5   0.889383
# 6   0.912691
# 7   0.897548
# 8   0.922675
# 9   0.841785
# 10  0.925354
# 11  0.901527
# 12  0.827769
# 13  0.920873
# 14  0.913270

# %%
cb = dfs2[2][['test_score']]
cb = cb.rename(columns = {'test_score':'CatBoost'})
cb
# Out:
#     CatBoost
# 0   0.926457
# 1   0.902353
# 2   0.935233
# 3   0.929956
# 4   0.948118
# 5   0.936021
# 6   0.944510
# 7   0.922645
# 8   0.945339
# 9   0.880212
# 10  0.942003
# 11  0.924434
# 12  0.871441
# 13  0.934365
# 14  0.942280

# %%
combo = pd.concat([SLR1, SLR2, MLR, elastic_df, RF, ridge_df, lasso_df, xgb, gb, cb], axis=1)
combo
# Out:
#     SLR (Area)  SLR (Quality)  MLR (Area & Quality)  ElasticNet  \
# 0     0.492545       0.601363              0.721532    0.896418
# 1     0.500684       0.604992              0.714287    0.846425
# 2     0.530382       0.631919              0.736684    0.853683
# 3     0.553000       0.612772              0.755845    0.892887
# 4     0.509211       0.664951              0.751330    0.922612
# 5     0.503816       0.620319              0.724462    0.908357
# 6     0.569944       0.654626              0.782182    0.880169
# 7     0.515928       0.612257              0.724543    0.904719
# 8     0.493042       0.645844              0.747638    0.905795
# 9     0.505414       0.592861              0.708893    0.848192
# 10    0.557953       0.636823              0.764368    0.907414
# 11    0.480105       0.646617              0.720255    0.883031
# 12    0.428189       0.582898              0.654818    0.829967
# 13    0.565351       0.628856              0.766435    0.896447
# 14    0.525359       0.607640              0.745547    0.903938
#
#     Random Forest     Ridge     Lasso       XGB  Gradient Boost  CatBoost
# 0        0.897587  0.906132  0.910384  0.904162        0.914769  0.926457
# 1        0.856902  0.858186  0.858097  0.829442        0.828986  0.902353
# 2        0.898612  0.776873  0.776695  0.913540        0.919118  0.935233
# 3        0.879042  0.921208  0.921014  0.890408        0.905515  0.929956
# 4        0.919555  0.943573  0.943476  0.922078        0.935739  0.948118
# 5        0.897254  0.916243  0.913753  0.889383        0.909002  0.936021
# 6        0.906944  0.883911  0.883419  0.912691        0.925711  0.944510
# 7        0.893468  0.924162  0.925780  0.897548        0.911508  0.922645
# 8        0.913180  0.926505  0.926305  0.922675        0.929292  0.945339
# 9        0.847973  0.867633  0.867655  0.841785        0.838481  0.880212
# 10       0.913801  0.916545  0.916492  0.925354        0.935408  0.942003
# 11       0.884819  0.907745  0.907447  0.901527        0.908924  0.924434
# 12       0.823639  0.804888  0.804559  0.827769        0.817532  0.871441
# 13       0.906415  0.911361  0.914910  0.920873        0.916969  0.934365
# 14       0.909470  0.921205  0.921261  0.913270        0.922299  0.942280

# %%
g4, g7, g9 = sns.color_palette("muted", 3)

# %%
sns.color_palette("muted", 3)
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803)]

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

legend_elements = [Line2D([0],[0], marker='o', markersize=10, color='w', lw=0, markeredgecolor='black', label='Mean 5-Fold (x3) CV Score'),
                   Patch(facecolor=g4, edgecolor='black', label='Linear Models'),
                   Patch(facecolor=g7, edgecolor='black', label='Penalized Models'),
                   Patch(facecolor=g9, edgecolor='black', label='Tree-Based Models')]

plt.style.use('default')
plt.style.use('ggplot')

plt.figure(figsize=(12,6))

my_pal = {"SLR (Area)":g4, "SLR (Quality)":g4, "MLR (Area & Quality)":g4,
         "Ridge":g7, "Lasso":g7, "ElasticNet":g7,
         "Random Forest":g9, "Gradient Boost": g9, "XGB":g9, "CatBoost":g9}

ax = sns.boxplot(data=combo, showmeans=True,
                        meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"}, palette=my_pal)

leg = ax.legend(handles=legend_elements, loc='lower right', fontsize=15)
leg.get_frame().set_linewidth(0.75)
leg.get_frame().set_edgecolor('black')

plt.xticks(rotation=35, fontsize=14)
plt.yticks(fontsize=12)
plt.ylabel('R-Squared', fontsize=18, color='blue')
plt.xlabel('Model', fontsize=18, color='blue')

plt.title('Model Performance Using 5-Fold Cross Validation (x3 Repeats)', fontsize=24, color='blue')

#colors = [g4, g4, g4, g7, g7, g7, g9, g9, g9, g9]
#for xtick, color in zip(ax.get_xticklabels(), colors):
#    xtick.set_color(color)

plt.tight_layout();

# %%
combo.describe()
# Out:
#        SLR (Area)  SLR (Quality)  MLR (Area & Quality)  ElasticNet  \
# count   15.000000      15.000000             15.000000   15.000000
# mean     0.515395       0.622983              0.734588    0.885337
# std      0.037207       0.023780              0.030715    0.027831
# min      0.428189       0.582898              0.654818    0.829967
# 25%      0.496863       0.606316              0.720893    0.866926
# 50%      0.509211       0.620319              0.736684    0.896418
# 75%      0.541691       0.641334              0.753587    0.905257
# max      0.569944       0.664951              0.782182    0.922612
#
#        Random Forest      Ridge      Lasso        XGB  Gradient Boost  \
# count      15.000000  15.000000  15.000000  15.000000       15.000000
# mean        0.889911   0.892411   0.892750   0.894167        0.901283
# std         0.027414   0.047243   0.047501   0.033706        0.039048
# min         0.823639   0.776873   0.776695   0.827769        0.817532
# 25%         0.881930   0.875772   0.875537   0.889896        0.907219
# 50%         0.897587   0.911361   0.913753   0.904162        0.914769
# 75%         0.908207   0.921206   0.921137   0.917206        0.924005
# max         0.919555   0.943573   0.943476   0.925354        0.935739
#
#         CatBoost
# count  15.000000
# mean    0.925691
# std     0.023365
# min     0.871441
# 25%     0.923539
# 50%     0.934365
# 75%     0.942142
# max     0.948118
