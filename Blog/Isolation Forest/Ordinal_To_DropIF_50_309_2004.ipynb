# %%
import pandas as pd
import seaborn as sns
pd.set_option("display.max_columns", 300)

# %%
ordinal = pd.read_csv('../Data/BaseOrdinal.csv')

# %%
ordinal.shape
# Out:
# (2580, 81)

# %%
ordinal.head(3)
# Out:
#    Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 0           0          3          3         3         3          3
# 1           1          4          3         4         3          3
# 2           2          4          3         3         3          5
#
#    KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  GarageCond  \
# 0            3           8            4             1           3           3
# 1            4           8            0             3           3           3
# 2            4           8            0             1           3           1
#
#    PoolQC  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0       0       5.0     1.0    1.0       3.0          3.0        0.0
# 1       0       5.0     1.0    1.0       3.0          3.0        0.0
# 2       0       1.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# ...

# %%
ordinal.loc[[50, 309, 2004]]
# Out:
#       Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 50            50          3          3         3         3          2
# 309          309          5          3         5         3          5
# 2004        2004          4          4         3         3          5
#
#       KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  \
# 50              3           6            0             0           0
# 309             5           8            4             3           3
# 2004            5           8            3             1           5
#
#       GarageCond  PoolQC  MSZoning  Street  Alley  LotShape  LandContour  \
# 50             0       0       5.0     1.0    1.0       3.0          3.0
# 309            3       0       5.0     1.0    1.0       0.0          0.0
# 2004           3       0       6.0     1.0    1.0       1.0          3.0
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %%
ordinal.loc[[50, 309, 2004]]
# Out:
#       Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 50            50          3          3         3         3          2
# 309          309          5          3         5         3          5
# 2004        2004          4          4         3         3          5
#
#       KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  \
# 50              3           6            0             0           0
# 309             5           8            4             3           3
# 2004            5           8            3             1           5
#
#       GarageCond  PoolQC  MSZoning  Street  Alley  LotShape  LandContour  \
# 50             0       0       5.0     1.0    1.0       3.0          3.0
# 309            3       0       5.0     1.0    1.0       0.0          0.0
# 2004           3       0       6.0     1.0    1.0       1.0          3.0
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %%
ordinal_dropIF = ordinal.drop([50, 309, 2004])

# %%
ordinal_dropIF.shape
# Out:
# (2577, 81)

# %%
ordinal_dropIF.iloc[48:52]
# Out:
#     Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 48          48          3          3         3         3          3
# 49          49          3          3         3         3          4
# 51          51          4          3         4         3          5
# 52          52          3          3         4         3          5
#
#     KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  \
# 48            3           8            4             0           0
# 49            3           8            0             1           3
# 51            4           8            0             3           3
# 52            3           8            3             3           3
#
#     GarageCond  PoolQC  MSZoning  Street  Alley  LotShape  LandContour  \
# 48           0       0       6.0     1.0    0.0       3.0          3.0
# 49           3       0       6.0     1.0    0.0       3.0          3.0
# 51           3       0       2.0     1.0    2.0       0.0          3.0
# ...

# %%
ordinal_dropIF.iloc[307:311]
# Out:
#      Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 308         308          4          3         4         3          5
# 310         310          3          3         3         3          5
# 311         311          3          3         3         3          3
# 312         312          4          3         4         3          5
#
#      KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  \
# 308            4           8            4             3           3
# 310            3           8            0             1           3
# 311            3           8            3             3           3
# 312            4           8            4             3           3
#
#      GarageCond  PoolQC  MSZoning  Street  Alley  LotShape  LandContour  \
# 308           3       0       5.0     1.0    1.0       0.0          3.0
# 310           3       0       6.0     1.0    1.0       3.0          3.0
# ...

# %%
ordinal_dropIF.iloc[2000:2006]
# Out:
#       Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 2002        2002          3          3         3         3          4
# 2003        2003          3          3         4         3          3
# 2005        2005          3          3         3         3          3
# 2006        2006          3          4         3         3          5
# 2007        2007          4          3         4         3          3
# 2008        2008          3          3         0         0          5
#
#       KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  \
# 2002            3           8            3             1           3
# 2003            3           8            0             0           0
# 2005            3           8            3             2           3
# 2006            3           8            2             3           3
# 2007            3           8            3             2           3
# ...

# %%
ordinal_dropIF.to_csv('OrdinalDropIF50_309_2004.csv', index=False)
