# %%
import pandas as pd
import seaborn as sns
pd.set_option("display.max_columns", 300)

# %%
ordinal = pd.read_csv('../Data/BaseOrdinal.csv')

# %%
ordinal.shape
# Out:
# (2580, 81)

# %%
ordinal.head(3)
# Out:
#    Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 0           0          3          3         3         3          3
# 1           1          4          3         4         3          3
# 2           2          4          3         3         3          5
#
#    KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  GarageCond  \
# 0            3           8            4             1           3           3
# 1            4           8            0             3           3           3
# 2            4           8            0             1           3           1
#
#    PoolQC  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0       0       5.0     1.0    1.0       3.0          3.0        0.0
# 1       0       5.0     1.0    1.0       3.0          3.0        0.0
# 2       0       1.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# ...

# %%
ordinal.loc[[309]]
# Out:
#      Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 309         309          5          3         5         3          5
#
#      KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  \
# 309            5           8            4             3           3
#
#      GarageCond  PoolQC  MSZoning  Street  Alley  LotShape  LandContour  \
# 309           3       0       5.0     1.0    1.0       0.0          0.0
#
#      Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 309        0.0        4.0        0.0           7.0         4.0         4.0
#
#      BldgType  HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 309       0.0         5.0        3.0       0.0          5.0          5.0
#
#      MasVnrType  Foundation  BsmtExposure  BsmtFinType1  BsmtFinType2  \
# 309         3.0         2.0           1.0           2.0           6.0
#
#      Heating  CentralAir  Electrical  GarageType  PavedDrive  Fence  \
# ...

# %%
ordinal.loc[309]
# Out:
# Unnamed: 0       309.0
# ExterQual          5.0
# ExterCond          3.0
# BsmtQual           5.0
# BsmtCond           3.0
#                  ...
# BsmtFullBath       1.0
# BsmtHalfBath       0.0
# GarageYrBlt     2007.0
# GarageCars         3.0
# GarageArea       884.0
# Name: 309, Length: 81, dtype: float64

# %%
ordinal_dropIF = ordinal.drop(309)

# %%
ordinal_dropIF.shape
# Out:
# (2579, 81)

# %%
ordinal_dropIF.iloc[306:312]
# Out:
#      Unnamed: 0  ExterQual  ExterCond  BsmtQual  BsmtCond  HeatingQC  \
# 306         306          3          3         4         3          4
# 307         307          3          3         3         3          5
# 308         308          4          3         4         3          5
# 310         310          3          3         3         3          5
# 311         311          3          3         3         3          3
# 312         312          4          3         4         3          5
#
#      KitchenQual  Functional  FireplaceQu  GarageFinish  GarageQual  \
# 306            4           8            3             3           3
# 307            3           8            3             2           3
# 308            4           8            4             3           3
# 310            3           8            0             1           3
# 311            3           8            3             3           3
# 312            4           8            4             3           3
#
# ...

# %%
ordinal_dropIF.to_csv('OrdinalDropIF309.csv', index=False)
