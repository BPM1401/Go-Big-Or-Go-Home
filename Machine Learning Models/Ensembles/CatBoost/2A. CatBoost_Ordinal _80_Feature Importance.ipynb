# %%
import pandas as pd
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_rows", 100)
pd.set_option("max_colwidth", 200)

import numpy as np

#import sklearn 

#from numpy import mean
#from numpy import std

#from sklearn.preprocessing import StandardScaler

from catboost import CatBoostRegressor

#from sklearn.ensemble import StackingRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedKFold

#from sklearn.metrics import make_scorer

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ordinal = pd.read_csv('../../../Data/BaseOrdinal.csv')
ordinal.shape
# Out:
# (2580, 83)

# %%
ordinal = ordinal.drop(['Unnamed: 0', 'PID', 'Unnamed: 0.1'], axis=1)
ordinal.shape
# Out:
# (2580, 80)

# %%
ordinal.head(3)
# Out:
#    MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0         6.0       5.0     1.0    1.0       3.0          3.0        0.0
# 1         0.0       5.0     1.0    1.0       3.0          3.0        0.0
# 2         6.0       1.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0        0.0        0.0          21.0         2.0         2.0       0.0
# 1        4.0        0.0           7.0         2.0         2.0       4.0
# 2        4.0        0.0          11.0         2.0         2.0       0.0
#
#    HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0         2.0        1.0       0.0         13.0         14.0         2.0
# 1         2.0        1.0       0.0          6.0          6.0         1.0
# 2         2.0        3.0       0.0          8.0          8.0         2.0
#
#    ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0        3.0        4.0         1.0       5.0       5.0           3.0
# 1        2.0        4.0         1.0       2.0       5.0           2.0
# 2        2.0        4.0         0.0       5.0       5.0           3.0
#
#    BsmtFinType1  BsmtFinType2  Heating  HeatingQC  CentralAir  Electrical  \
# 0           5.0           6.0      1.0        4.0         1.0         4.0
# 1           2.0           0.0      1.0        4.0         1.0         4.0
# 2           0.0           6.0      1.0        0.0         1.0         4.0
#
#    KitchenQual  Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 0          4.0         6.0          2.0         5.0           3.0         5.0
# 1          2.0         6.0          3.0         1.0           0.0         5.0
# 2          2.0         6.0          3.0         5.0           3.0         5.0
#
#    GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  MoSold  YrSold  \
# 0         5.0         2.0     3.0    4.0          1.0     5.0     4.0
# 1         5.0         2.0     3.0    4.0          1.0     4.0     3.0
# 2         4.0         0.0     3.0    4.0          1.0     2.0     1.0
#
#    SaleType  SaleCondition  GrLivArea  SalePrice  LotFrontage  LotArea  \
# 0       9.0            4.0        856     126000    68.516053     7890
# 1       9.0            4.0       1049     139500    42.000000     4235
# 2       9.0            4.0       1001     124900    60.000000     6060
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0            6            6       1939          1950         0.0       238.0
# 1            5            5       1984          1984       149.0       552.0
# 2            5            9       1930          2007         0.0       737.0
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0         0.0      618.0        856.0       856         0             0
# 1       393.0      104.0       1049.0      1049         0             0
# 2         0.0      100.0        837.0      1001         0             0
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         1         0             2             1
# 1           1.0           0.0         2         0             2             1
# 2           0.0           0.0         1         0             2             1
#
#    TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  \
# 0             4           1       1939.0         2.0       399.0           0
# 1             5           0       1984.0         1.0       266.0           0
# 2             5           0       1930.0         1.0       216.0         154
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal
# 0            0              0          0          166         0        0
# 1          105              0          0            0         0        0
# 2            0             42         86            0         0        0

# %%
X = ordinal.drop(['SalePrice'], axis=1)
y = ordinal.SalePrice

# %%
CB = CatBoostRegressor()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25)
    
CB.fit(X_train, Y_train, verbose=False)
y_pred = CB.predict(X_test)

CB_Score = r2_score(Y_test, y_pred)
CB_Score
# Out:
# 0.9345260435597063

# %%
feature_importance = CB.feature_importances_
sorted_idx = np.argsort(feature_importance)

fig = plt.figure(figsize=(12, 25))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X_test.columns)[sorted_idx])
plt.title('Feature Importance');

# %%
X_cols = ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, CB.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('OverallQual', 21.72421596301292),
#  ('GrLivArea', 16.92726135053131),
#  ('1stFlrSF', 5.1136583607553),
#  ('YearBuilt', 4.4309373689836615),
#  ('BsmtFinSF1', 3.9797385529544167),
#  ('TotalBsmtSF', 3.3175308118202427),
#  ('LotArea', 3.187728270577467),
#  ('Fireplaces', 2.598486189635692),
#  ('BsmtQual', 2.4980772366233692),
#  ('GarageCars', 2.281809164722691),
#  ('FullBath', 2.159621702401953),
#  ('GarageType', 2.0760425138611955),
#  ('GarageArea', 2.014141525800715),
#  ('ExterQual', 1.9194713160246761),
#  ('Neighborhood', 1.795783679977202),
#  ('YearRemodAdd', 1.7391184416942358),
#  ('OverallCond', 1.410375667596299),
#  ('KitchenQual', 1.3563926193829603),
#  ('BsmtFullBath', 1.3189611100438392),
#  ('MasVnrArea', 1.137947352667308),
#  ('GarageYrBlt', 1.0602984608259773),
#  ('2ndFlrSF', 0.9852225876080297),
#  ('LotFrontage', 0.8286479466012776),
#  ('BsmtFinType1', 0.778007086754255),
#  ('HalfBath', 0.7601786369977286),
#  ('WoodDeckSF', 0.7505505872400445),
#  ('BedroomAbvGr', 0.7318685258919114),
#  ('HeatingQC', 0.7034328170415178),
#  ('BsmtExposure', 0.5970937013389319),
#  ('SaleCondition', 0.5751521559144721),
#  ('CentralAir', 0.5165764079360006),
#  ('OpenPorchSF', 0.4966843067573668),
#  ('FireplaceQu', 0.48386052704005533),
#  ('LotShape', 0.4759648518417578),
#  ('ScreenPorch', 0.43967325085276543),
#  ('MoSold', 0.4382580031260254),
#  ('BldgType', 0.4193487545477359),
#  ('LandContour', 0.4082124010945919),
#  ('MSSubClass', 0.3691842793204495),
#  ('PavedDrive', 0.3648340693597579),
#  ('BsmtUnfSF', 0.34921011287599996),
#  ('Condition1', 0.3360444077456267),
#  ('Functional', 0.3132210963454272),
#  ('Exterior1st', 0.2982699793272111),
#  ('Foundation', 0.2603394686165163),
#  ('MSZoning', 0.2533646309982353),
#  ('HouseStyle', 0.23968785457910832),
#  ('GarageQual', 0.223494260897286),
#  ('YrSold', 0.21656301685286578),
#  ('Fence', 0.2088222072506777),
#  ('GarageCond', 0.20288019615543504),
#  ('MasVnrType', 0.19617858843611496),
#  ('GarageFinish', 0.16874874051763752),
#  ('TotRmsAbvGrd', 0.16803054719118296),
#  ('RoofStyle', 0.1607455486314524),
#  ('EnclosedPorch', 0.1564463588267745),
#  ('RoofMatl', 0.1255167896831474),
#  ('LotConfig', 0.1197281865156261),
#  ('Exterior2nd', 0.09716685288098642),
#  ('Alley', 0.0936120688672874),
#  ('SaleType', 0.09252966254903834),
#  ('BsmtFinType2', 0.08962276338394197),
#  ('KitchenAbvGr', 0.08534120031588169),
#  ('Condition2', 0.0806995178982818),
#  ('BsmtFinSF2', 0.08040011406517449),
#  ('LandSlope', 0.05848461763770754),
#  ('BsmtHalfBath', 0.03829710718429145),
#  ('LowQualFinSF', 0.03035920285814114),
#  ('ExterCond', 0.028982857560323164),
#  ('Electrical', 0.02246795545438487),
#  ('3SsnPorch', 0.010693065685610358),
#  ('MiscVal', 0.007242083211896923),
#  ('Heating', 0.005215082530690075),
#  ('BsmtCond', 0.005041008064838967),
#  ('PoolArea', 0.004467245955124005),
#  ('Street', 0.0012325515355838413),
#  ('PoolQC', 0.0005005756369524072),
#  ('MiscFeature', 3.918119416037425e-06),
#  ('Utilities', 0.0)]
