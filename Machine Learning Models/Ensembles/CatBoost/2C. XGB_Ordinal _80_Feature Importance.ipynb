# %%
import pandas as pd
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_rows", 100)
pd.set_option("max_colwidth", 200)

import numpy as np

#import sklearn 

#from numpy import mean
#from numpy import std

#from sklearn.preprocessing import StandardScaler

#from catboost import CatBoostRegressor
from xgboost import XGBRegressor

#from sklearn.ensemble import StackingRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedKFold

#from sklearn.metrics import make_scorer

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ordinal = pd.read_csv('../../../Data/BaseOrdinal.csv')
ordinal.shape
# Out:
# (2580, 83)

# %%
ordinal = ordinal.drop(['Unnamed: 0', 'PID', 'Unnamed: 0.1'], axis=1)
ordinal.shape
# Out:
# (2580, 80)

# %%
ordinal.head(3)
# Out:
#    MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0         6.0       5.0     1.0    1.0       3.0          3.0        0.0
# 1         0.0       5.0     1.0    1.0       3.0          3.0        0.0
# 2         6.0       1.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0        0.0        0.0          21.0         2.0         2.0       0.0
# 1        4.0        0.0           7.0         2.0         2.0       4.0
# 2        4.0        0.0          11.0         2.0         2.0       0.0
#
#    HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0         2.0        1.0       0.0         13.0         14.0         2.0
# 1         2.0        1.0       0.0          6.0          6.0         1.0
# 2         2.0        3.0       0.0          8.0          8.0         2.0
#
#    ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0        3.0        4.0         1.0       5.0       5.0           3.0
# 1        2.0        4.0         1.0       2.0       5.0           2.0
# 2        2.0        4.0         0.0       5.0       5.0           3.0
#
#    BsmtFinType1  BsmtFinType2  Heating  HeatingQC  CentralAir  Electrical  \
# 0           5.0           6.0      1.0        4.0         1.0         4.0
# 1           2.0           0.0      1.0        4.0         1.0         4.0
# 2           0.0           6.0      1.0        0.0         1.0         4.0
#
#    KitchenQual  Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 0          4.0         6.0          2.0         5.0           3.0         5.0
# 1          2.0         6.0          3.0         1.0           0.0         5.0
# 2          2.0         6.0          3.0         5.0           3.0         5.0
#
#    GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  MoSold  YrSold  \
# 0         5.0         2.0     3.0    4.0          1.0     5.0     4.0
# 1         5.0         2.0     3.0    4.0          1.0     4.0     3.0
# 2         4.0         0.0     3.0    4.0          1.0     2.0     1.0
#
#    SaleType  SaleCondition  GrLivArea  SalePrice  LotFrontage  LotArea  \
# 0       9.0            4.0        856     126000    68.516053     7890
# 1       9.0            4.0       1049     139500    42.000000     4235
# 2       9.0            4.0       1001     124900    60.000000     6060
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0            6            6       1939          1950         0.0       238.0
# 1            5            5       1984          1984       149.0       552.0
# 2            5            9       1930          2007         0.0       737.0
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0         0.0      618.0        856.0       856         0             0
# 1       393.0      104.0       1049.0      1049         0             0
# 2         0.0      100.0        837.0      1001         0             0
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         1         0             2             1
# 1           1.0           0.0         2         0             2             1
# 2           0.0           0.0         1         0             2             1
#
#    TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  \
# 0             4           1       1939.0         2.0       399.0           0
# 1             5           0       1984.0         1.0       266.0           0
# 2             5           0       1930.0         1.0       216.0         154
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal
# 0            0              0          0          166         0        0
# 1          105              0          0            0         0        0
# 2            0             42         86            0         0        0

# %%
X = ordinal.drop(['SalePrice'], axis=1)
y = ordinal.SalePrice

# %%
xgb = XGBRegressor()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25)
    
xgb.fit(X_train, Y_train, verbose=False)
y_pred = xgb.predict(X_test)

XGB_Score = r2_score(Y_test, y_pred)
XGB_Score
# Out:
# 0.9160030660366245

# %%
feature_importance = xgb.feature_importances_
sorted_idx = np.argsort(feature_importance)

fig = plt.figure(figsize=(12, 25))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X_test.columns)[sorted_idx])
plt.title('Feature Importance');

# %%
X_cols = ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, xgb.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('OverallQual', 0.5865),
#  ('GrLivArea', 0.043775976),
#  ('BsmtQual', 0.04266923),
#  ('FullBath', 0.038716808),
#  ('GarageCars', 0.02858274),
#  ('TotalBsmtSF', 0.026710143),
#  ('Fireplaces', 0.024528375),
#  ('1stFlrSF', 0.022746291),
#  ('CentralAir', 0.020211162),
#  ('ExterQual', 0.01663839),
#  ('BsmtFinSF1', 0.014846778),
#  ('YearRemodAdd', 0.008757488),
#  ('LandContour', 0.005812668),
#  ('SaleCondition', 0.0057829283),
#  ('YearBuilt', 0.005635514),
#  ('PavedDrive', 0.0048860945),
#  ('GarageArea', 0.004877223),
#  ('OverallCond', 0.0048722858),
#  ('Heating', 0.004832421),
#  ('BsmtFullBath', 0.004777761),
#  ('BsmtFinType1', 0.004675366),
#  ('GarageCond', 0.0040326347),
#  ('LotArea', 0.0039269235),
#  ('KitchenQual', 0.003871567),
#  ('BedroomAbvGr', 0.0035506776),
#  ('2ndFlrSF', 0.0034503418),
#  ('ScreenPorch', 0.0033507866),
#  ('LowQualFinSF', 0.003154515),
#  ('MSZoning', 0.002835212),
#  ('BsmtHalfBath', 0.0027708057),
#  ('GarageType', 0.0027145923),
#  ('Condition1', 0.0027113194),
#  ('BsmtExposure', 0.0026129428),
#  ('HalfBath', 0.0025046074),
#  ('WoodDeckSF', 0.0023216293),
#  ('Foundation', 0.0022785922),
#  ('OpenPorchSF', 0.0022135049),
#  ('LotFrontage', 0.0021645988),
#  ('Functional', 0.002157589),
#  ('SaleType', 0.0021142233),
#  ('Neighborhood', 0.001990609),
#  ('Alley', 0.0017621411),
#  ('MasVnrArea', 0.0017173517),
#  ('GarageFinish', 0.001557676),
#  ('GarageYrBlt', 0.0012190373),
#  ('EnclosedPorch', 0.0011892011),
#  ('HeatingQC', 0.001008616),
#  ('BldgType', 0.0009856861),
#  ('FireplaceQu', 0.0009838005),
#  ('TotRmsAbvGrd', 0.00097106217),
#  ('RoofStyle', 0.0009452579),
#  ('LandSlope', 0.0008627531),
#  ('ExterCond', 0.0007824581),
#  ('Exterior1st', 0.00077128044),
#  ('BsmtUnfSF', 0.00075977744),
#  ('Exterior2nd', 0.0006199069),
#  ('Fence', 0.00060146855),
#  ('HouseStyle', 0.0005445146),
#  ('BsmtFinType2', 0.0005294168),
#  ('MoSold', 0.00051994435),
#  ('MSSubClass', 0.0005156287),
#  ('BsmtFinSF2', 0.00041619982),
#  ('YrSold', 0.0004063349),
#  ('LotConfig', 0.00039316792),
#  ('BsmtCond', 0.0003549488),
#  ('PoolQC', 0.000345416),
#  ('GarageQual', 0.00030859787),
#  ('LotShape', 0.0002970837),
#  ('MasVnrType', 0.00024229864),
#  ('Electrical', 0.00014963474),
#  ('MiscVal', 0.00014702082),
#  ('KitchenAbvGr', 0.00012210263),
#  ('RoofMatl', 9.6700765e-05),
#  ('PoolArea', 8.3995496e-05),
#  ('3SsnPorch', 8.097196e-05),
#  ('MiscFeature', 8.003697e-05),
#  ('Condition2', 6.279384e-05),
#  ('Street', 2.5011268e-06),
#  ('Utilities', 0.0)]
