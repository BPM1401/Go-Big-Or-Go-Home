# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", 300)

from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import SequentialFeatureSelector

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
import sklearn.ensemble
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
base_ordinal = pd.read_csv('../Data/BaseOrdinal.csv')
base_ordinal.shape
# Out:
# (2580, 83)

# %%
xgb = XGBRegressor()

# %%
X = base_ordinal.drop(['SalePrice'], axis=1).values
y = base_ordinal.SalePrice.values

# %%
xgb.fit(X,y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb.score(X,y)
# Out:
# 0.9986916564520045

# %%
X_cols = base_ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, xgb.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('OverallQual', 0.6113876),
#  ('GarageCars', 0.05972298),
#  ('GrLivArea', 0.05133951),
#  ('CentralAir', 0.028709799),
#  ('TotalBsmtSF', 0.027240546),
#  ('BsmtQual', 0.016487366),
#  ('1stFlrSF', 0.014890318),
#  ('BsmtFinSF1', 0.013533816),
#  ('YearBuilt', 0.011999053),
#  ('ExterQual', 0.011280087),
#  ('Fireplaces', 0.011214813),
#  ('GarageType', 0.010065013),
#  ('GarageArea', 0.009732357),
#  ('LandContour', 0.007917272),
#  ('BsmtFinType1', 0.0069311718),
#  ('BsmtCond', 0.006316797),
#  ('HalfBath', 0.0055111824),
#  ('SaleCondition', 0.005242437),
#  ('MSZoning', 0.005061879),
#  ('YearRemodAdd', 0.0048684026),
#  ('KitchenQual', 0.0045760414),
#  ('MasVnrArea', 0.0040832823),
#  ('ScreenPorch', 0.0040660114),
#  ('BldgType', 0.0040459936),
#  ('PavedDrive', 0.0039911014),
#  ('BedroomAbvGr', 0.0036779647),
#  ('LotArea', 0.0035938362),
#  ('OverallCond', 0.003297503),
#  ('BsmtFullBath', 0.0032570872),
#  ('2ndFlrSF', 0.0031346108),
#  ('RoofMatl', 0.0024249286),
#  ('Condition1', 0.002177908),
#  ('Neighborhood', 0.002057249),
#  ('Functional', 0.001992142),
#  ('Exterior2nd', 0.001826739),
#  ('HeatingQC', 0.0016054492),
#  ('OpenPorchSF', 0.0015533506),
#  ('LotFrontage', 0.0015466978),
#  ('PID', 0.0014432655),
#  ('ExterCond', 0.0014414361),
#  ('BsmtExposure', 0.0013856087),
#  ('Alley', 0.0013624873),
#  ('KitchenAbvGr', 0.0012908552),
#  ('BsmtHalfBath', 0.0012720416),
#  ('GarageCond', 0.0012414454),
#  ('FullBath', 0.0011932799),
#  ('LandSlope', 0.0011599343),
#  ('BsmtFinSF2', 0.0011354728),
#  ('MSSubClass', 0.0010182469),
#  ('BsmtUnfSF', 0.0010053901),
#  ('WoodDeckSF', 0.0009402311),
#  ('BsmtFinType2', 0.0007875116),
#  ('Unnamed: 0.1', 0.00078649534),
#  ('GarageYrBlt', 0.000735949),
#  ('EnclosedPorch', 0.0007310451),
#  ('MoSold', 0.00071216334),
#  ('Fence', 0.00067440874),
#  ('GarageFinish', 0.0006304261),
#  ('Exterior1st', 0.0006028537),
#  ('YrSold', 0.000513785),
#  ('MasVnrType', 0.0005053337),
#  ('FireplaceQu', 0.0004890022),
#  ('GarageQual', 0.0003940684),
#  ('Electrical', 0.0003647736),
#  ('HouseStyle', 0.00036268678),
#  ('TotRmsAbvGrd', 0.00035894552),
#  ('LotShape', 0.00035813494),
#  ('Foundation', 0.00035126857),
#  ('Unnamed: 0', 0.0003113728),
#  ('LotConfig', 0.00029532326),
#  ('3SsnPorch', 0.00027414688),
#  ('MiscFeature', 0.00026894806),
#  ('MiscVal', 0.00026252843),
#  ('RoofStyle', 0.0002509225),
#  ('SaleType', 0.00023993864),
#  ('LowQualFinSF', 0.00021686534),
#  ('Condition2', 0.00015193813),
#  ('PoolArea', 0.00010031176),
#  ('Heating', 1.1800938e-05),
#  ('Street', 6.9958355e-06),
#  ('Utilities', 0.0),
#  ('PoolQC', 0.0)]

# %%
a, b = zip(*sorted_importance[0:15]) # this splits the list of tuples into two lists
pd.DataFrame({'feature_name':a, 'importance_score':b}).plot.bar(x='feature_name',y='importance_score', legend=None)
plt.title('Top 15 Feature Importance Plot of Basic XGB');

# %% [markdown]
# ## No Scaling.....vs ##

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb.score(X_train, y_train)
# Out:
# 0.9995143407777297

# %%
xgb.score(X_test, y_test)
# Out:
# 0.900531361105303

# %%
X_cols = base_ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, xgb.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('OverallQual', 0.6325754),
#  ('GarageCars', 0.07582347),
#  ('GrLivArea', 0.05935529),
#  ('1stFlrSF', 0.033530455),
#  ('Fireplaces', 0.014717979),
#  ('GarageArea', 0.014350104),
#  ('BsmtFinSF1', 0.013982688),
#  ('TotalBsmtSF', 0.011644503),
#  ('GarageCond', 0.0099181095),
#  ('ExterQual', 0.009469479),
#  ('SaleCondition', 0.009085038),
#  ('CentralAir', 0.0084384605),
#  ('MSZoning', 0.007201201),
#  ('YearRemodAdd', 0.0069472026),
#  ('Alley', 0.00595792),
#  ('YearBuilt', 0.0059261653),
#  ('LotArea', 0.005434871),
#  ('2ndFlrSF', 0.00529685),
#  ('OverallCond', 0.0049463543),
#  ('LandContour', 0.0034880207),
#  ('BsmtQual', 0.0031896231),
#  ('KitchenQual', 0.0029658782),
#  ('Functional', 0.0029090121),
#  ('BsmtFinType1', 0.0026948105),
#  ('LandSlope', 0.0023607833),
#  ('MasVnrArea', 0.0022080352),
#  ('Neighborhood', 0.002145967),
#  ('HeatingQC', 0.0021405236),
#  ('BsmtFullBath', 0.0018860504),
#  ('EnclosedPorch', 0.0018127072),
#  ('Condition1', 0.0017628602),
#  ('GarageYrBlt', 0.0017476224),
#  ('BsmtCond', 0.0015740786),
#  ('BsmtExposure', 0.0015106144),
#  ('ScreenPorch', 0.0014870228),
#  ('BedroomAbvGr', 0.0014678137),
#  ('GarageType', 0.001375511),
#  ('PavedDrive', 0.0013372976),
#  ('FireplaceQu', 0.0013252561),
#  ('Unnamed: 0.1', 0.0012667931),
#  ('MSSubClass', 0.0012270184),
#  ('LotFrontage', 0.0011761517),
#  ('Foundation', 0.0011144818),
#  ('BsmtUnfSF', 0.0011090017),
#  ('PID', 0.001080248),
#  ('HalfBath', 0.0010735774),
#  ('GarageQual', 0.00093341595),
#  ('BsmtFinSF2', 0.00093218207),
#  ('BldgType', 0.0009308363),
#  ('ExterCond', 0.0009120307),
#  ('WoodDeckSF', 0.0008971814),
#  ('Exterior1st', 0.00078483764),
#  ('LowQualFinSF', 0.0007636513),
#  ('TotRmsAbvGrd', 0.00075746735),
#  ('Heating', 0.0007480671),
#  ('OpenPorchSF', 0.000638527),
#  ('BsmtFinType2', 0.0005625084),
#  ('FullBath', 0.0005500986),
#  ('Exterior2nd', 0.00053503364),
#  ('3SsnPorch', 0.0005340159),
#  ('MoSold', 0.00052995526),
#  ('MasVnrType', 0.00047866625),
#  ('RoofStyle', 0.00045781658),
#  ('LotConfig', 0.00043352705),
#  ('GarageFinish', 0.0004254055),
#  ('YrSold', 0.0003952025),
#  ('LotShape', 0.0003781177),
#  ('HouseStyle', 0.00036541306),
#  ('Unnamed: 0', 0.00034627607),
#  ('Street', 0.0003304028),
#  ('Fence', 0.00031560907),
#  ('BsmtHalfBath', 0.0002941436),
#  ('MiscFeature', 0.00028847138),
#  ('Electrical', 0.00021179247),
#  ('SaleType', 0.00014279709),
#  ('MiscVal', 8.312189e-05),
#  ('RoofMatl', 5.151075e-06),
#  ('Utilities', 0.0),
#  ('Condition2', 0.0),
#  ('PoolQC', 0.0),
#  ('KitchenAbvGr', 0.0),
#  ('PoolArea', 0.0)]

# %%
a, b = zip(*sorted_importance[0:15]) # this splits the list of tuples into two lists
pd.DataFrame({'feature_name':a, 'importance_score':b}).plot.bar(x='feature_name',y='importance_score', legend=None)
plt.title('Top 15 Feature Importance Plot of Basic XGB');

# %%
predicted_value = xgb.predict(X_test)
true_value = y_test

# %%
plt.figure(figsize=(10,10))
plt.scatter(predicted_value, true_value, c='crimson')
#plt.yscale('log')
#plt.xscale('log')

plt.title('Gradient Boosting Regressor Base')
p1 = max(max(predicted_value), max(true_value))
p2 = min(min(predicted_value), min(true_value))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Predictions', fontsize=15)
plt.ylabel('True Values', fontsize=15)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Scaling.... ##

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb.score(X_train, y_train)
# Out:
# 0.9994964078730713

# %%
xgb.score(X_test, y_test)
# Out:
# 0.8768410345893902

# %%
X_cols = base_ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, xgb.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('OverallQual', 0.6290965),
#  ('FullBath', 0.066130325),
#  ('GrLivArea', 0.040381726),
#  ('GarageCars', 0.025643077),
#  ('Fireplaces', 0.02525778),
#  ('GarageType', 0.02022188),
#  ('TotalBsmtSF', 0.016778057),
#  ('BsmtQual', 0.01535011),
#  ('KitchenAbvGr', 0.013920328),
#  ('GarageArea', 0.012721843),
#  ('1stFlrSF', 0.009893144),
#  ('BsmtFinSF1', 0.009171245),
#  ('ExterQual', 0.008531519),
#  ('CentralAir', 0.0074716806),
#  ('BldgType', 0.0069473796),
#  ('KitchenQual', 0.0064697736),
#  ('MasVnrArea', 0.0062762704),
#  ('OverallCond', 0.0057605933),
#  ('BsmtFullBath', 0.0053462386),
#  ('YearRemodAdd', 0.0048150597),
#  ('HalfBath', 0.0038744279),
#  ('MSZoning', 0.0036708934),
#  ('YearBuilt', 0.0033580915),
#  ('SaleCondition', 0.002963747),
#  ('Functional', 0.0028650064),
#  ('GarageCond', 0.0027488254),
#  ('SaleType', 0.0025026987),
#  ('BedroomAbvGr', 0.0022562842),
#  ('LotArea', 0.0020918183),
#  ('2ndFlrSF', 0.0020527653),
#  ('BsmtFinType1', 0.0020324546),
#  ('BsmtExposure', 0.001989493),
#  ('RoofMatl', 0.001727339),
#  ('Foundation', 0.0017157153),
#  ('HeatingQC', 0.001676593),
#  ('ScreenPorch', 0.0015953155),
#  ('WoodDeckSF', 0.0014114265),
#  ('Neighborhood', 0.001404378),
#  ('Condition1', 0.0012313462),
#  ('GarageQual', 0.0010942325),
#  ('BsmtFinSF2', 0.0010723869),
#  ('LotFrontage', 0.0010389279),
#  ('PID', 0.0010173911),
#  ('OpenPorchSF', 0.000995283),
#  ('Street', 0.0009371794),
#  ('BsmtFinType2', 0.0009152539),
#  ('Fence', 0.000912012),
#  ('TotRmsAbvGrd', 0.0008664149),
#  ('Electrical', 0.00085873314),
#  ('LandSlope', 0.00084577163),
#  ('LotShape', 0.0007277879),
#  ('MoSold', 0.0006259364),
#  ('HouseStyle', 0.00059795764),
#  ('GarageYrBlt', 0.00057616713),
#  ('Exterior2nd', 0.0005611417),
#  ('EnclosedPorch', 0.00055211224),
#  ('Unnamed: 0.1', 0.0005083973),
#  ('LandContour', 0.0004965773),
#  ('BsmtUnfSF', 0.0004902278),
#  ('PavedDrive', 0.0004798726),
#  ('MSSubClass', 0.00045116767),
#  ('Exterior1st', 0.00044256577),
#  ('Alley', 0.00040038917),
#  ('YrSold', 0.00038464356),
#  ('Unnamed: 0', 0.00037563167),
#  ('LotConfig', 0.0003595886),
#  ('BsmtCond', 0.0003497309),
#  ('FireplaceQu', 0.0003492152),
#  ('3SsnPorch', 0.00023253683),
#  ('GarageFinish', 0.0002139691),
#  ('BsmtHalfBath', 0.00020964854),
#  ('RoofStyle', 0.00019645561),
#  ('MasVnrType', 0.00018823931),
#  ('ExterCond', 0.00018291578),
#  ('MiscVal', 0.00012319196),
#  ('LowQualFinSF', 1.7283264e-05),
#  ('Utilities', 0.0),
#  ('Condition2', 0.0),
#  ('Heating', 0.0),
#  ('PoolQC', 0.0),
#  ('MiscFeature', 0.0),
#  ('PoolArea', 0.0)]

# %%
a, b = zip(*sorted_importance[0:15]) # this splits the list of tuples into two lists
pd.DataFrame({'feature_name':a, 'importance_score':b}).plot.bar(x='feature_name',y='importance_score', legend=None)
plt.title('Top 15 Feature Importance Plot of Basic XGB');

# %%
predicted_value = xgb.predict(X_test)

# %%
true_value = y_test

# %%
plt.figure(figsize=(10,10))
plt.scatter(predicted_value, true_value, c='crimson')
#plt.yscale('log')
#plt.xscale('log')

plt.title('Gradient Boosting Regressor Base')
p1 = max(max(predicted_value), max(true_value))
p2 = min(min(predicted_value), min(true_value))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Predictions', fontsize=15)
plt.ylabel('True Values', fontsize=15)
plt.axis('equal')
plt.show()
