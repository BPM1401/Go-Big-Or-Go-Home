# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", 300)

# %%
R1 = pd.read_csv('Results1.csv')
R1
# Out:
#     GBM_R2_NLNS  GBM_AR2_NLNS  GBM MAE NLNS
# 0      0.899510      0.885256  14837.672725
# 1      0.930549      0.920697  13020.602476
# 2      0.925727      0.915192  13784.189397
# 3      0.851958      0.830959  13908.839993
# 4      0.855263      0.834733  13763.802619
# ..          ...           ...           ...
# 95     0.926421      0.915984  12951.939390
# 96     0.914240      0.902075  14024.867944
# 97     0.910360      0.897645  14216.994242
# 98     0.923679      0.912853  13159.233263
# 99     0.910739      0.898078  13945.361260
#
# [100 rows x 3 columns]

# %%
R2 = pd.read_csv('Results2.csv')
R2
# Out:
#     GBM_R2_NLYS  GBM_AR2_NLYS  GBM MAE NLYS
# 0      0.812018      0.785354  14489.394264
# 1      0.917311      0.905582  13409.884728
# 2      0.926840      0.916463  13457.706589
# 3      0.923794      0.912985  14530.221614
# 4      0.816465      0.790431  15003.096465
# ..          ...           ...           ...
# 95     0.844225      0.822129  15571.267076
# 96     0.830030      0.805920  13522.783177
# 97     0.875463      0.857798  15148.020551
# 98     0.816240      0.790175  14869.432243
# 99     0.910220      0.897486  13575.999594
#
# [100 rows x 3 columns]

# %%
R3 = pd.read_csv('Results3.csv')
R3
# Out:
#     GBM_R2_YLYS  GBM_AR2_YLYS  GBM MAE YLYS
# 0      0.913691      0.901449  13191.588121
# 1      0.906013      0.892682  14015.031559
# 2      0.925735      0.915201  13094.118599
# 3      0.912357      0.899926  12500.011199
# 4      0.925976      0.915476  13397.737691
# ..          ...           ...           ...
# 95     0.918800      0.907282  14216.986313
# 96     0.897056      0.882454  14480.315835
# 97     0.914098      0.901913  14812.355078
# 98     0.893245      0.878102  14339.340065
# 99     0.922422      0.911418  12865.092237
#
# [100 rows x 3 columns]

# %%
R4 = pd.read_csv('Results4.csv')
R4
# Out:
#     Ridge R2  R+GBM_R2_NLYS  R+GBM_AR2_NLYS  R+GBM MAE NLYS
# 0   0.939563       0.938714        0.929896    11842.395335
# 1   0.939563       0.951944        0.945031    11377.669910
# 2   0.939563       0.938159        0.929262    12080.904737
# 3   0.939563       0.913502        0.901058    12416.654516
# 4   0.939563       0.931341        0.921462    11499.362768
# ..       ...            ...             ...             ...
# 95  0.939563       0.918284        0.906528    12015.620861
# 96  0.939563       0.943594        0.935479    12117.024306
# 97  0.939563       0.942553        0.934288    11661.153866
# 98  0.939563       0.946772        0.939114    12068.363095
# 99  0.939563       0.912890        0.900357    12458.810648
#
# [100 rows x 4 columns]

# %%
R5 = pd.read_csv('Results5.csv')
R5
# Out:
#     Ridge R2  R+GBM_R2_YLYS  R+GBM_AR2_YLYS  R+GBM MAE YLYS
# 0   0.942863       0.913010        0.900494    11796.847219
# 1   0.942863       0.930914        0.920974    10468.805931
# 2   0.942863       0.898005        0.883331    11548.755547
# 3   0.942863       0.910605        0.897744    10631.441738
# 4   0.942863       0.913350        0.900883    11744.534035
# ..       ...            ...             ...             ...
# 95  0.942863       0.949164        0.941851    10972.686060
# 96  0.942863       0.943597        0.935482    12468.271738
# 97  0.942863       0.954247        0.947665    10652.590527
# 98  0.942863       0.944932        0.937009    10752.320867
# 99  0.942863       0.954571        0.948035     9870.030996
#
# [100 rows x 4 columns]

# %%
R6 = pd.read_csv('Results6.csv')
R6
# Out:
#     Ridge R2  IF+R+GBM_R2  IF+R+GBM_AR2  IF+R+GBM MAE
# 0   0.942625     0.930353      0.920333  11071.522522
# 1   0.947051     0.958256      0.952250  10127.824712
# 2   0.942625     0.910871      0.898047  11454.731990
# 3   0.946780     0.962161      0.956717  10158.778819
# 4   0.942221     0.921547      0.910260  10984.286920
# ..       ...          ...           ...           ...
# 95  0.947043     0.956675      0.950442  10699.340518
# 96  0.942572     0.909213      0.896152  11135.779153
# 97  0.947306     0.954255      0.947674  10027.681062
# 98  0.942923     0.905233      0.891599  12041.579827
# 99  0.947051     0.961783      0.956284  10121.956312
#
# [100 rows x 4 columns]

# %%
R7 = pd.read_csv('Results7.csv')
R7
# Out:
#     Ridge R2  IF+R+GBM_R2 II  IF+R+GBM_AR2 II  IF+R+GBM MAE II
# 0   0.946292        0.953051         0.946297     10505.691418
# 1   0.946316        0.955416         0.949002     10388.375067
# 2   0.950675        0.952380         0.945529     10320.298264
# 3   0.946328        0.953514         0.946826     10799.050432
# 4   0.946318        0.958944         0.953037     10157.648822
# ..       ...             ...              ...              ...
# 95  0.946482        0.955986         0.949654     10791.781103
# 96  0.950928        0.958045         0.952009     10372.979011
# 97  0.946199        0.958109         0.952082     10662.403802
# 98  0.946000        0.954208         0.947620     10668.285660
# 99  0.945828        0.955564         0.949170     10080.807872
#
# [100 rows x 4 columns]

# %%
R8 = pd.read_csv('Results8.csv')
R8
# Out:
#     Ridge (TT Split) R2  R(TT)+GBM_R2_NLYS  R(TT)+GBM_AR2_NLYS  \
# 0              0.904174           0.916040            0.903961
# 1              0.862238           0.861088            0.841102
# 2              0.892591           0.875237            0.857287
# 3              0.918966           0.920806            0.909412
# 4              0.924149           0.932897            0.923243
# ..                  ...                ...                 ...
# 95             0.827092           0.846683            0.824624
# 96             0.918690           0.926094            0.915461
# 97             0.910863           0.922485            0.911332
# 98             0.925101           0.934597            0.925187
# 99             0.921367           0.927727            0.917328
#
#     R(TT)+GBM MAE NLYS
# 0         14113.129753
# 1         13188.339777
# 2         13039.212508
# 3         13592.969639
# 4         12722.062795
# ..                 ...
# 95        14395.084155
# ...

# %%
combo = pd.concat([R1, R2, R3, R4, R5, R6, R7, R8], axis=1)
combo
# Out:
#     GBM_R2_NLNS  GBM_AR2_NLNS  GBM MAE NLNS  GBM_R2_NLYS  GBM_AR2_NLYS  \
# 0      0.899510      0.885256  14837.672725     0.812018      0.785354
# 1      0.930549      0.920697  13020.602476     0.917311      0.905582
# 2      0.925727      0.915192  13784.189397     0.926840      0.916463
# 3      0.851958      0.830959  13908.839993     0.923794      0.912985
# 4      0.855263      0.834733  13763.802619     0.816465      0.790431
# ..          ...           ...           ...          ...           ...
# 95     0.926421      0.915984  12951.939390     0.844225      0.822129
# 96     0.914240      0.902075  14024.867944     0.830030      0.805920
# 97     0.910360      0.897645  14216.994242     0.875463      0.857798
# 98     0.923679      0.912853  13159.233263     0.816240      0.790175
# 99     0.910739      0.898078  13945.361260     0.910220      0.897486
#
#     GBM MAE NLYS  GBM_R2_YLYS  GBM_AR2_YLYS  GBM MAE YLYS  Ridge R2  \
# ...

# %%
combo.describe()
# Out:
#        GBM_R2_NLNS  GBM_AR2_NLNS  GBM MAE NLNS  GBM_R2_NLYS  GBM_AR2_NLYS  \
# count   100.000000    100.000000    100.000000   100.000000    100.000000
# mean      0.894370      0.879387  13978.240945     0.903062      0.889312
# std       0.035211      0.040206    668.085407     0.031062      0.035468
# min       0.808477      0.781310  12518.716902     0.812018      0.785354
# 25%       0.859647      0.839738  13573.631382     0.899938      0.885745
# 50%       0.909888      0.897107  13892.752936     0.914025      0.901830
# 75%       0.924204      0.913453  14416.186188     0.923677      0.912851
# max       0.937956      0.929155  15927.352975     0.934804      0.925556
#
#        GBM MAE NLYS  GBM_R2_YLYS  GBM_AR2_YLYS  GBM MAE YLYS      Ridge R2  \
# count    100.000000   100.000000    100.000000    100.000000  1.000000e+02
# mean   13936.108682     0.907851      0.894781  13769.088133  9.395630e-01
# std      614.317549     0.013902      0.015874    625.729609  8.926529e-16
# ...

# %%
sns.boxplot(data=combo[['GBM_AR2_NLNS', 'GBM_AR2_NLYS', 'GBM_AR2_YLYS', 
                        'R+GBM_AR2_NLYS', 'R+GBM_AR2_YLYS', 'IF+R+GBM_AR2', 
                        'IF+R+GBM_AR2 II', 'R(TT)+GBM_AR2_NLYS']])
plt.xticks(rotation=25);

# %%
sns.boxplot(data=combo[['GBM_AR2_NLNS', 'GBM_AR2_NLYS', 'GBM_AR2_YLYS', 
                        'R(TT)+GBM_AR2_NLYS']], showmeans=True,  
                       meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"8"})
plt.xticks(rotation=25);

# %%
sns.boxplot(data=combo[['GBM MAE NLNS', 'GBM MAE NLYS', 'GBM MAE YLYS', 
                        'R+GBM MAE NLYS', 'R+GBM MAE YLYS', 'IF+R+GBM MAE',
                       'IF+R+GBM MAE II', 'R(TT)+GBM MAE NLYS']])
plt.xticks(rotation=25);
