# %%
import pandas as pd
import numpy as np

from numpy import mean
from numpy import std

from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedKFold

from matplotlib import pyplot
import seaborn as sns

# %%
# Basic Ordinal Encoded Dataset for Non-Linear Models
ordinal = pd.read_csv('../Data/BaseOrdinal.csv')

# %%
X = ordinal.drop(['SalePrice'], axis=1).values
y = ordinal.SalePrice.values

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# list of other models to evaluate

def get_models():
    models = dict()
    models['gradient boost'] = GradientBoostingRegressor()
    models['Xtreme GB'] = XGBRegressor()
    models['CatBoost'] = CatBoostRegressor(verbose=False)
    return models

# %%
scoring = {'r2': 'r2',
           'neg_mae': 'neg_mean_absolute_error'
          }

# %%
# Use cross-validation to evaluate model performance

def evaluate_model(model, X, y):
    
    # define the evaluation procedure
    cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=1)
    
    # evaluate the model and collect the results
    scores = cross_validate(model, X, y, scoring=scoring, 
                                  cv=cv, n_jobs=-1) 
    
    df = pd.DataFrame(scores)
    
    return df

# %%
models = get_models()

# %%
#Create List of Dictionaries to evalute models

dfs = list()

for name, model in models.items():
    
    # evaluate the model
    df = evaluate_model(model, X, y)
    dfs.append(df)

# %%
dfs
# Out:
# [    fit_time  score_time   test_r2  test_neg_mae
#  0   1.161350    0.003893  0.918704 -14260.797797
#  1   1.251343    0.002760  0.835483 -13957.677704
#  2   1.223046    0.001663  0.919861 -14060.019107
#  3   1.244690    0.002435  0.902871 -13594.939836
#  4   1.208242    0.001380  0.925753 -13450.500594
#  5   1.188439    0.001363  0.910583 -15200.815979
#  6   1.208277    0.001474  0.921980 -12757.214066
#  7   1.227155    0.001339  0.898601 -13569.569801
#  8   1.092249    0.002667  0.927782 -13154.529173
#  9   1.084204    0.003142  0.851347 -15542.987957
#  10  1.109346    0.001204  0.937369 -13076.651464
#  11  1.074592    0.001584  0.914829 -14168.783033
#  12  1.083887    0.001152  0.813151 -13555.696475
#  13  1.098856    0.001115  0.922897 -13319.430698
#  14  1.079312    0.001138  0.928267 -13491.985435,
#       fit_time  score_time   test_r2  test_neg_mae
#  0   22.313726    0.035451  0.906994 -15045.726464
#  1   20.972948    0.036042  0.844876 -15091.184385
#  2   23.175889    0.044081  0.917901 -14514.431345
#  3   23.581128    0.006276  0.889401 -15014.851131
#  4   22.678122    0.045040  0.919365 -14513.341373
#  5   20.640346    0.047851  0.886927 -16294.422208
#  6   22.191338    0.042817  0.907978 -13837.085294
#  7   23.628514    0.009979  0.900390 -14452.474344
#  8    7.909073    0.006367  0.919377 -14098.179657
#  9    7.759517    0.006594  0.824601 -16530.938908
#  10   6.605467    0.004524  0.925821 -13938.570252
#  11   6.457940    0.004993  0.888153 -16301.455934
#  12   6.151658    0.004795  0.818443 -15267.304657
#  13   5.670470    0.003410  0.909209 -14399.586255
#  14   5.349592    0.002541  0.905740 -14598.583735,
#      fit_time  score_time   test_r2  test_neg_mae
#  0   6.935022    0.020221  0.930637 -12458.598681
#  1   7.133013    0.017481  0.903094 -12068.154461
#  2   7.254792    0.015291  0.935673 -12285.637600
#  3   7.281632    0.075961  0.929734 -11867.911520
#  4   7.200921    0.019362  0.950324 -11318.734225
#  5   6.985428    0.043583  0.936665 -12521.387238
#  6   7.120869    0.020878  0.941445 -10996.331917
#  7   7.810397    0.021477  0.923793 -12130.609562
#  8   6.495483    0.016618  0.944311 -11558.860150
#  9   6.483175    0.011895  0.887027 -14002.878030
#  10  6.505483    0.012041  0.944348 -11599.594120
#  11  6.789977    0.011508  0.925164 -13159.715691
#  12  6.397674    0.011632  0.866493 -12375.815752
#  13  6.283245    0.012556  0.940461 -11475.113551
#  14  6.464522    0.011302  0.940444 -12142.670994]

# %%
gb_df = dfs[0][['test_r2', 'test_neg_mae']]
gb_df = gb_df.assign(MAE = gb_df['test_neg_mae'].abs())
gb_df = gb_df.rename(columns = {'test_r2':'GB R2', 'MAE':'GB MAE'})
gb_df
# Out:
#        GB R2  test_neg_mae        GB MAE
# 0   0.918704 -14260.797797  14260.797797
# 1   0.835483 -13957.677704  13957.677704
# 2   0.919861 -14060.019107  14060.019107
# 3   0.902871 -13594.939836  13594.939836
# 4   0.925753 -13450.500594  13450.500594
# 5   0.910583 -15200.815979  15200.815979
# 6   0.921980 -12757.214066  12757.214066
# 7   0.898601 -13569.569801  13569.569801
# 8   0.927782 -13154.529173  13154.529173
# 9   0.851347 -15542.987957  15542.987957
# 10  0.937369 -13076.651464  13076.651464
# 11  0.914829 -14168.783033  14168.783033
# 12  0.813151 -13555.696475  13555.696475
# 13  0.922897 -13319.430698  13319.430698
# 14  0.928267 -13491.985435  13491.985435

# %%
xgb_df = dfs[1][['test_r2', 'test_neg_mae']]
xgb_df = xgb_df.assign(MAE = xgb_df['test_neg_mae'].abs())
xgb_df = xgb_df.rename(columns = {'test_r2':'XGB R2', 'MAE':'XGB MAE'})
xgb_df
# Out:
#       XGB R2  test_neg_mae       XGB MAE
# 0   0.906994 -15045.726464  15045.726464
# 1   0.844876 -15091.184385  15091.184385
# 2   0.917901 -14514.431345  14514.431345
# 3   0.889401 -15014.851131  15014.851131
# 4   0.919365 -14513.341373  14513.341373
# 5   0.886927 -16294.422208  16294.422208
# 6   0.907978 -13837.085294  13837.085294
# 7   0.900390 -14452.474344  14452.474344
# 8   0.919377 -14098.179657  14098.179657
# 9   0.824601 -16530.938908  16530.938908
# 10  0.925821 -13938.570252  13938.570252
# 11  0.888153 -16301.455934  16301.455934
# 12  0.818443 -15267.304657  15267.304657
# 13  0.909209 -14399.586255  14399.586255
# 14  0.905740 -14598.583735  14598.583735

# %%
cat = dfs[2][['test_r2', 'test_neg_mae']]
cat = cat.assign(MAE = cat['test_neg_mae'].abs())
cat = cat.rename(columns = {'test_r2':'Cat R2', 'MAE':'Cat MAE'})
cat
# Out:
#       Cat R2  test_neg_mae       Cat MAE
# 0   0.930637 -12458.598681  12458.598681
# 1   0.903094 -12068.154461  12068.154461
# 2   0.935673 -12285.637600  12285.637600
# 3   0.929734 -11867.911520  11867.911520
# 4   0.950324 -11318.734225  11318.734225
# 5   0.936665 -12521.387238  12521.387238
# 6   0.941445 -10996.331917  10996.331917
# 7   0.923793 -12130.609562  12130.609562
# 8   0.944311 -11558.860150  11558.860150
# 9   0.887027 -14002.878030  14002.878030
# 10  0.944348 -11599.594120  11599.594120
# 11  0.925164 -13159.715691  13159.715691
# 12  0.866493 -12375.815752  12375.815752
# 13  0.940461 -11475.113551  11475.113551
# 14  0.940444 -12142.670994  12142.670994

# %%
dfs
# Out:
# [    fit_time  score_time   test_r2  test_neg_mae
#  0   1.161350    0.003893  0.918704 -14260.797797
#  1   1.251343    0.002760  0.835483 -13957.677704
#  2   1.223046    0.001663  0.919861 -14060.019107
#  3   1.244690    0.002435  0.902871 -13594.939836
#  4   1.208242    0.001380  0.925753 -13450.500594
#  5   1.188439    0.001363  0.910583 -15200.815979
#  6   1.208277    0.001474  0.921980 -12757.214066
#  7   1.227155    0.001339  0.898601 -13569.569801
#  8   1.092249    0.002667  0.927782 -13154.529173
#  9   1.084204    0.003142  0.851347 -15542.987957
#  10  1.109346    0.001204  0.937369 -13076.651464
#  11  1.074592    0.001584  0.914829 -14168.783033
#  12  1.083887    0.001152  0.813151 -13555.696475
#  13  1.098856    0.001115  0.922897 -13319.430698
#  14  1.079312    0.001138  0.928267 -13491.985435,
#       fit_time  score_time   test_r2  test_neg_mae
#  0   22.313726    0.035451  0.906994 -15045.726464
#  1   20.972948    0.036042  0.844876 -15091.184385
#  2   23.175889    0.044081  0.917901 -14514.431345
#  3   23.581128    0.006276  0.889401 -15014.851131
#  4   22.678122    0.045040  0.919365 -14513.341373
#  5   20.640346    0.047851  0.886927 -16294.422208
#  6   22.191338    0.042817  0.907978 -13837.085294
#  7   23.628514    0.009979  0.900390 -14452.474344
#  8    7.909073    0.006367  0.919377 -14098.179657
#  9    7.759517    0.006594  0.824601 -16530.938908
#  10   6.605467    0.004524  0.925821 -13938.570252
#  11   6.457940    0.004993  0.888153 -16301.455934
#  12   6.151658    0.004795  0.818443 -15267.304657
#  13   5.670470    0.003410  0.909209 -14399.586255
#  14   5.349592    0.002541  0.905740 -14598.583735,
#      fit_time  score_time   test_r2  test_neg_mae
#  0   6.935022    0.020221  0.930637 -12458.598681
#  1   7.133013    0.017481  0.903094 -12068.154461
#  2   7.254792    0.015291  0.935673 -12285.637600
#  3   7.281632    0.075961  0.929734 -11867.911520
#  4   7.200921    0.019362  0.950324 -11318.734225
#  5   6.985428    0.043583  0.936665 -12521.387238
#  6   7.120869    0.020878  0.941445 -10996.331917
#  7   7.810397    0.021477  0.923793 -12130.609562
#  8   6.495483    0.016618  0.944311 -11558.860150
#  9   6.483175    0.011895  0.887027 -14002.878030
#  10  6.505483    0.012041  0.944348 -11599.594120
#  11  6.789977    0.011508  0.925164 -13159.715691
#  12  6.397674    0.011632  0.866493 -12375.815752
#  13  6.283245    0.012556  0.940461 -11475.113551
#  14  6.464522    0.011302  0.940444 -12142.670994]

# %%
box = pd.concat([gb_df, xgb_df, cat], axis=1)
box
# Out:
#        GB R2  test_neg_mae        GB MAE    XGB R2  test_neg_mae  \
# 0   0.918704 -14260.797797  14260.797797  0.906994 -15045.726464
# 1   0.835483 -13957.677704  13957.677704  0.844876 -15091.184385
# 2   0.919861 -14060.019107  14060.019107  0.917901 -14514.431345
# 3   0.902871 -13594.939836  13594.939836  0.889401 -15014.851131
# 4   0.925753 -13450.500594  13450.500594  0.919365 -14513.341373
# 5   0.910583 -15200.815979  15200.815979  0.886927 -16294.422208
# 6   0.921980 -12757.214066  12757.214066  0.907978 -13837.085294
# 7   0.898601 -13569.569801  13569.569801  0.900390 -14452.474344
# 8   0.927782 -13154.529173  13154.529173  0.919377 -14098.179657
# 9   0.851347 -15542.987957  15542.987957  0.824601 -16530.938908
# 10  0.937369 -13076.651464  13076.651464  0.925821 -13938.570252
# 11  0.914829 -14168.783033  14168.783033  0.888153 -16301.455934
# 12  0.813151 -13555.696475  13555.696475  0.818443 -15267.304657
# 13  0.922897 -13319.430698  13319.430698  0.909209 -14399.586255
# 14  0.928267 -13491.985435  13491.985435  0.905740 -14598.583735
#
#          XGB MAE    Cat R2  test_neg_mae       Cat MAE
# 0   15045.726464  0.930637 -12458.598681  12458.598681
# 1   15091.184385  0.903094 -12068.154461  12068.154461
# 2   14514.431345  0.935673 -12285.637600  12285.637600
# 3   15014.851131  0.929734 -11867.911520  11867.911520
# 4   14513.341373  0.950324 -11318.734225  11318.734225
# 5   16294.422208  0.936665 -12521.387238  12521.387238
# 6   13837.085294  0.941445 -10996.331917  10996.331917
# 7   14452.474344  0.923793 -12130.609562  12130.609562
# 8   14098.179657  0.944311 -11558.860150  11558.860150
# 9   16530.938908  0.887027 -14002.878030  14002.878030
# 10  13938.570252  0.944348 -11599.594120  11599.594120
# 11  16301.455934  0.925164 -13159.715691  13159.715691
# 12  15267.304657  0.866493 -12375.815752  12375.815752
# 13  14399.586255  0.940461 -11475.113551  11475.113551
# 14  14598.583735  0.940444 -12142.670994  12142.670994

# %%
sns.boxplot(data=box[['GB R2', 'XGB R2', 'Cat R2']], showmeans=True,
           meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"8"});

# %%
box.describe()
# Out:
#            GB R2  test_neg_mae        GB MAE     XGB R2  test_neg_mae  \
# count  15.000000     15.000000     15.000000  15.000000     15.000000
# mean    0.901965 -13810.773275  13810.773275   0.891012 -14926.542396
# std     0.037549    759.202073    759.202073   0.034387    857.760419
# min     0.813151 -15542.987957  12757.214066   0.818443 -16530.938908
# 25%     0.900736 -14114.401070  13384.965646   0.887540 -15179.244521
# 50%     0.918704 -13569.569801  13569.569801   0.905740 -14598.583735
# 75%     0.924325 -13384.965646  14114.401070   0.913555 -14426.030300
# max     0.937369 -12757.214066  15542.987957   0.925821 -13837.085294
#
#             XGB MAE     Cat R2  test_neg_mae       Cat MAE
# count     15.000000  15.000000     15.000000     15.000000
# mean   14926.542396   0.926641 -12130.800899  12130.800899
# std      857.760419   0.023523    754.331560    754.331560
# min    13837.085294   0.866493 -14002.878030  10996.331917
# 25%    14426.030300   0.924479 -12417.207216  11579.227135
# 50%    14598.583735   0.935673 -12130.609562  12130.609562
# 75%    15179.244521   0.940953 -11579.227135  12417.207216
# max    16530.938908   0.950324 -10996.331917  14002.878030

# %%
box.to_csv('Gradient_Boost.csv', index=False)
