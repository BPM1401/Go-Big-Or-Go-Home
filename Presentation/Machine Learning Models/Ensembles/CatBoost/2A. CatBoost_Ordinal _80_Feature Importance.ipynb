# %%
import pandas as pd
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_rows", 100)
pd.set_option("max_colwidth", 200)

import numpy as np

#import sklearn 

#from numpy import mean
#from numpy import std

#from sklearn.preprocessing import StandardScaler

from catboost import CatBoostRegressor

#from sklearn.ensemble import StackingRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedKFold

#from sklearn.metrics import make_scorer

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ordinal = pd.read_csv('../../../Data/BaseOrdinal.csv')
ordinal.shape
# Out:
# (2580, 83)

# %%
ordinal = ordinal.drop(['Unnamed: 0', 'PID', 'Unnamed: 0.1'], axis=1)
ordinal.shape
# Out:
# (2580, 80)

# %%
ordinal.head(3)
# Out:
#    MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0         6.0       5.0     1.0    1.0       3.0          3.0        0.0
# 1         0.0       5.0     1.0    1.0       3.0          3.0        0.0
# 2         6.0       1.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0        0.0        0.0          21.0         2.0         2.0       0.0
# 1        4.0        0.0           7.0         2.0         2.0       4.0
# 2        4.0        0.0          11.0         2.0         2.0       0.0
#
#    HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0         2.0        1.0       0.0         13.0         14.0         2.0
# 1         2.0        1.0       0.0          6.0          6.0         1.0
# 2         2.0        3.0       0.0          8.0          8.0         2.0
#
#    ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0        3.0        4.0         1.0       5.0       5.0           3.0
# 1        2.0        4.0         1.0       2.0       5.0           2.0
# 2        2.0        4.0         0.0       5.0       5.0           3.0
#
#    BsmtFinType1  BsmtFinType2  Heating  HeatingQC  CentralAir  Electrical  \
# 0           5.0           6.0      1.0        4.0         1.0         4.0
# 1           2.0           0.0      1.0        4.0         1.0         4.0
# 2           0.0           6.0      1.0        0.0         1.0         4.0
#
#    KitchenQual  Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 0          4.0         6.0          2.0         5.0           3.0         5.0
# 1          2.0         6.0          3.0         1.0           0.0         5.0
# 2          2.0         6.0          3.0         5.0           3.0         5.0
#
#    GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  MoSold  YrSold  \
# 0         5.0         2.0     3.0    4.0          1.0     5.0     4.0
# 1         5.0         2.0     3.0    4.0          1.0     4.0     3.0
# 2         4.0         0.0     3.0    4.0          1.0     2.0     1.0
#
#    SaleType  SaleCondition  GrLivArea  SalePrice  LotFrontage  LotArea  \
# 0       9.0            4.0        856     126000    68.516053     7890
# 1       9.0            4.0       1049     139500    42.000000     4235
# 2       9.0            4.0       1001     124900    60.000000     6060
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0            6            6       1939          1950         0.0       238.0
# 1            5            5       1984          1984       149.0       552.0
# 2            5            9       1930          2007         0.0       737.0
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0         0.0      618.0        856.0       856         0             0
# 1       393.0      104.0       1049.0      1049         0             0
# 2         0.0      100.0        837.0      1001         0             0
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         1         0             2             1
# 1           1.0           0.0         2         0             2             1
# 2           0.0           0.0         1         0             2             1
#
#    TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  \
# 0             4           1       1939.0         2.0       399.0           0
# 1             5           0       1984.0         1.0       266.0           0
# 2             5           0       1930.0         1.0       216.0         154
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal
# 0            0              0          0          166         0        0
# 1          105              0          0            0         0        0
# 2            0             42         86            0         0        0

# %%
X = ordinal.drop(['SalePrice'], axis=1)
y = ordinal.SalePrice

# %%
CB = CatBoostRegressor()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25, random_state=1)
    
CB.fit(X_train, Y_train, verbose=False)
y_pred = CB.predict(X_test)

CB_Score = r2_score(Y_test, y_pred)
CB_Score
# Out:
# 0.9256410119289216

# %%
feature_importance = CB.feature_importances_
sorted_idx = np.argsort(feature_importance)

fig = plt.figure(figsize=(12, 25))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X_test.columns)[sorted_idx])
plt.title('Feature Importance');

# %%
X_cols = ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, CB.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('OverallQual', 20.535044969829663),
#  ('GrLivArea', 15.78645571796096),
#  ('TotalBsmtSF', 5.040592164715882),
#  ('BsmtFinSF1', 4.122117799691082),
#  ('1stFlrSF', 3.6510868240305667),
#  ('BsmtQual', 3.4991585952425455),
#  ('LotArea', 3.2190953651108387),
#  ('GarageCars', 3.145705286192955),
#  ('Fireplaces', 2.9665531792546935),
#  ('YearBuilt', 2.8688158428355335),
#  ('GarageType', 2.2203873716714817),
#  ('KitchenQual', 2.0977851722628036),
#  ('2ndFlrSF', 2.083291387327653),
#  ('FullBath', 1.9801762595009769),
#  ('ExterQual', 1.9235661802415827),
#  ('Neighborhood', 1.7303902734481835),
#  ('YearRemodAdd', 1.516421703145135),
#  ('GarageYrBlt', 1.4971887478990622),
#  ('MasVnrArea', 1.4878580881527634),
#  ('OverallCond', 1.4668682108727191),
#  ('GarageArea', 1.2801153369853842),
#  ('BsmtExposure', 1.1438897742219314),
#  ('HalfBath', 1.131026841292115),
#  ('BsmtFinType1', 1.0638257020189006),
#  ('TotRmsAbvGrd', 0.9043470114723128),
#  ('LotFrontage', 0.8712340250353906),
#  ('BsmtFullBath', 0.7661572469400474),
#  ('CentralAir', 0.6636326123438874),
#  ('WoodDeckSF', 0.6584672909948386),
#  ('SaleCondition', 0.5991648784010165),
#  ('OpenPorchSF', 0.5314124891811031),
#  ('HeatingQC', 0.5273893193234189),
#  ('BsmtUnfSF', 0.5038079679343318),
#  ('MSZoning', 0.4518534235781717),
#  ('BldgType', 0.4441000328616277),
#  ('PavedDrive', 0.43310813328553605),
#  ('MoSold', 0.4021900862526474),
#  ('BedroomAbvGr', 0.3850959000266228),
#  ('LandContour', 0.3353269769760339),
#  ('MSSubClass', 0.33059028961262565),
#  ('Exterior1st', 0.3258453564281738),
#  ('Condition1', 0.3204928988192081),
#  ('YrSold', 0.27892751200370014),
#  ('FireplaceQu', 0.2636059430840814),
#  ('Functional', 0.20523290880442696),
#  ('MasVnrType', 0.19936958662822143),
#  ('Exterior2nd', 0.19584123788111155),
#  ('KitchenAbvGr', 0.1630731898221255),
#  ('LandSlope', 0.15532776587520736),
#  ('ScreenPorch', 0.15380750766124646),
#  ('BsmtFinSF2', 0.14867087303775361),
#  ('GarageCond', 0.14714341153810143),
#  ('EnclosedPorch', 0.1233931693264399),
#  ('HouseStyle', 0.12103598374117308),
#  ('SaleType', 0.09190838399427771),
#  ('Condition2', 0.09060168350341391),
#  ('Foundation', 0.08719080314018672),
#  ('GarageFinish', 0.07680980681287647),
#  ('RoofStyle', 0.07649773408412515),
#  ('LotShape', 0.06750918941547458),
#  ('BsmtFinType2', 0.06722760317160269),
#  ('LotConfig', 0.061445338785864306),
#  ('ExterCond', 0.05988991276103389),
#  ('BsmtCond', 0.052902899275986966),
#  ('Electrical', 0.04079047440564607),
#  ('GarageQual', 0.03481395540903846),
#  ('Heating', 0.032733635297382664),
#  ('LowQualFinSF', 0.01880777799459996),
#  ('3SsnPorch', 0.017603314180460666),
#  ('Alley', 0.01608078786204557),
#  ('RoofMatl', 0.012560877835376206),
#  ('BsmtHalfBath', 0.01049370305738397),
#  ('Fence', 0.009735280119810985),
#  ('MiscVal', 0.003655009551384187),
#  ('PoolArea', 0.0018915259199248846),
#  ('PoolQC', 0.0010153851693261592),
#  ('MiscFeature', 0.000773095476771371),
#  ('Street', 0.0),
#  ('Utilities', 0.0)]
