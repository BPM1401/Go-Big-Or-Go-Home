# %%
import pandas as pd
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_rows", 100)
pd.set_option("max_colwidth", 200)

import numpy as np

#import sklearn 

#from numpy import mean
#from numpy import std

#from sklearn.preprocessing import StandardScaler

from catboost import CatBoostRegressor

#from sklearn.ensemble import StackingRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedKFold

#from sklearn.metrics import make_scorer

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ordinal = pd.read_csv('../../../Data/BaseOrdinal2.csv')
ordinal.shape
# Out:
# (2580, 84)

# %%
ordinal = ordinal.drop(['Unnamed: 0', 'PID', 'Unnamed: 0.1'], axis=1)
ordinal.shape
# Out:
# (2580, 81)

# %%
ordinal.head(3)
# Out:
#    MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0         6.0       5.0     1.0    1.0       3.0          3.0        0.0
# 1         0.0       5.0     1.0    1.0       3.0          3.0        0.0
# 2         6.0       1.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0        0.0        0.0          21.0         2.0         2.0       0.0
# 1        4.0        0.0           7.0         2.0         2.0       4.0
# 2        4.0        0.0          11.0         2.0         2.0       0.0
#
#    HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0         2.0        1.0       0.0         13.0         14.0         2.0
# 1         2.0        1.0       0.0          6.0          6.0         1.0
# 2         2.0        3.0       0.0          8.0          8.0         2.0
#
#    ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0        3.0        4.0         1.0       5.0       5.0           3.0
# 1        2.0        4.0         1.0       2.0       5.0           2.0
# 2        2.0        4.0         0.0       5.0       5.0           3.0
#
#    BsmtFinType1  BsmtFinType2  Heating  HeatingQC  CentralAir  Electrical  \
# 0           5.0           6.0      1.0        4.0         1.0         3.0
# 1           2.0           0.0      1.0        4.0         1.0         3.0
# 2           0.0           6.0      1.0        0.0         1.0         3.0
#
#    KitchenQual  Functional  FireplaceQu  GarageType  GarageYrBlt  \
# 0          4.0         6.0          2.0         5.0         29.0
# 1          2.0         6.0          3.0         1.0         73.0
# 2          2.0         6.0          3.0         5.0         20.0
#
#    GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  Fence  \
# 0           3.0         5.0         5.0         2.0     3.0    4.0
# 1           0.0         5.0         5.0         2.0     3.0    4.0
# 2           3.0         5.0         4.0         0.0     3.0    4.0
#
#    MiscFeature    MoSold  YrSold  SaleType  SaleCondition  GrLivArea  \
# 0          1.0  0.866028     4.0       9.0            4.0        856
# 1          1.0  0.500004     3.0       9.0            4.0       1049
# 2          1.0 -0.499998     1.0       9.0            4.0       1001
#
#    SalePrice  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0     126000        81.46     7890            6            6       1939
# 1     139500        42.00     4235            5            5       1984
# 2     124900        60.00     6060            5            9       1930
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          1950         0.0       238.0         0.0      618.0        856.0
# 1          1984       149.0       552.0       393.0      104.0       1049.0
# 2          2007         0.0       737.0         0.0      100.0        837.0
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0       856         0             0           1.0           0.0         1
# 1      1049         0             0           1.0           0.0         2
# 2      1001         0             0           0.0           0.0         1
#
#    HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  \
# 0         0             2             1             4           1         2.0
# 1         0             2             1             5           0         1.0
# 2         0             2             1             5           0         1.0
#
#    GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0       399.0           0            0              0          0          166
# 1       266.0           0          105              0          0            0
# 2       216.0         154            0             42         86            0
#
#    PoolArea  MiscVal    QA
# 0         0        0  5136
# 1         0        0  5245
# 2         0        0  5005

# %%
X = ordinal.drop(['SalePrice'], axis=1)
y = ordinal.SalePrice

# %%
CB = CatBoostRegressor()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25)
    
CB.fit(X_train, Y_train, verbose=False)
y_pred = CB.predict(X_test)

CB_Score = r2_score(Y_test, y_pred)
CB_Score
# Out:
# 0.8764111965530639

# %%
feature_importance = CB.feature_importances_
sorted_idx = np.argsort(feature_importance)

fig = plt.figure(figsize=(12, 25))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X_test.columns)[sorted_idx])
plt.title('Feature Importance');

# %%
X_cols = ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, CB.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('QA', 35.5696997515067),
#  ('TotalBsmtSF', 6.72470155140583),
#  ('OverallQual', 5.003739108666983),
#  ('BsmtFinSF1', 4.400778095948106),
#  ('YearBuilt', 4.141481821733761),
#  ('KitchenQual', 3.604937517827025),
#  ('GrLivArea', 3.1020543972524077),
#  ('LotArea', 3.011062654507665),
#  ('1stFlrSF', 2.7588699535089725),
#  ('YearRemodAdd', 2.399290388351481),
#  ('Fireplaces', 2.3708830716268934),
#  ('ExterQual', 1.795949402629517),
#  ('GarageCars', 1.7959237150620995),
#  ('BsmtQual', 1.7412724529976626),
#  ('GarageType', 1.3704856147533644),
#  ('OverallCond', 1.2737702583676054),
#  ('Neighborhood', 1.2505690294699814),
#  ('BsmtExposure', 1.1677135242993733),
#  ('MasVnrArea', 1.0444079782134115),
#  ('2ndFlrSF', 0.908705316709249),
#  ('GarageArea', 0.8981363378819728),
#  ('CentralAir', 0.7908463225509168),
#  ('GarageYrBlt', 0.785311337589158),
#  ('BsmtFinType1', 0.68157623448778),
#  ('LotFrontage', 0.6602417651914342),
#  ('SaleCondition', 0.6129382908628597),
#  ('BsmtFullBath', 0.5884980531352403),
#  ('PavedDrive', 0.5698016639628194),
#  ('MSZoning', 0.5404546056968378),
#  ('WoodDeckSF', 0.4923395368499668),
#  ('HeatingQC', 0.47915246037470804),
#  ('OpenPorchSF', 0.4640687754269701),
#  ('LotShape', 0.41606166607511164),
#  ('Exterior1st', 0.40879311737697527),
#  ('Functional', 0.3759467636840453),
#  ('BsmtUnfSF', 0.37452176979632806),
#  ('BedroomAbvGr', 0.3684551679359358),
#  ('HouseStyle', 0.3407393834711157),
#  ('FireplaceQu', 0.3020371106264494),
#  ('LandContour', 0.2916783943357814),
#  ('TotRmsAbvGrd', 0.282907832630205),
#  ('MSSubClass', 0.28166877209289587),
#  ('YrSold', 0.26332279234743444),
#  ('MasVnrType', 0.2505951343015757),
#  ('ScreenPorch', 0.24051429867731197),
#  ('Condition1', 0.23660302092912758),
#  ('GarageCond', 0.21488206264261706),
#  ('MoSold', 0.21038593928500166),
#  ('HalfBath', 0.19717598752988133),
#  ('FullBath', 0.186015197416629),
#  ('LandSlope', 0.15303926970047735),
#  ('GarageFinish', 0.14679892020603452),
#  ('Exterior2nd', 0.14641564943480917),
#  ('KitchenAbvGr', 0.1455849708671363),
#  ('Electrical', 0.1268941910835255),
#  ('EnclosedPorch', 0.11259030668642979),
#  ('BldgType', 0.11071591903118799),
#  ('SaleType', 0.09475269068543019),
#  ('BsmtFinSF2', 0.09323540247325908),
#  ('RoofStyle', 0.08788050291118871),
#  ('LotConfig', 0.08580427697490037),
#  ('BsmtCond', 0.07880045481797697),
#  ('BsmtFinType2', 0.05917154007396269),
#  ('Foundation', 0.05607999519561452),
#  ('BsmtHalfBath', 0.049447247923704446),
#  ('ExterCond', 0.030493742333260847),
#  ('Alley', 0.030438434014631782),
#  ('Fence', 0.029502757034446447),
#  ('RoofMatl', 0.02732906109154602),
#  ('LowQualFinSF', 0.022362453744230758),
#  ('MiscVal', 0.019416203635198498),
#  ('PoolQC', 0.01856807092237153),
#  ('PoolArea', 0.012080776911461047),
#  ('GarageQual', 0.008747362492875995),
#  ('Condition2', 0.00396707974172331),
#  ('3SsnPorch', 0.0037081072743149705),
#  ('MiscFeature', 0.0031394077606038636),
#  ('Heating', 0.001069804974527274),
#  ('Street', 0.0),
#  ('Utilities', 0.0)]
