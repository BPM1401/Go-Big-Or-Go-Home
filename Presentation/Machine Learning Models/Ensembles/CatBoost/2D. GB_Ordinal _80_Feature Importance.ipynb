# %%
import pandas as pd
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_rows", 100)
pd.set_option("max_colwidth", 200)

import numpy as np

#import sklearn 

#from numpy import mean
#from numpy import std

#from sklearn.preprocessing import StandardScaler

#from catboost import CatBoostRegressor
#from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor


#from sklearn.ensemble import StackingRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import RepeatedKFold

#from sklearn.metrics import make_scorer

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ordinal = pd.read_csv('../../../Data/BaseOrdinal.csv')
ordinal.shape
# Out:
# (2580, 83)

# %%
ordinal = ordinal.drop(['Unnamed: 0', 'PID', 'Unnamed: 0.1'], axis=1)
ordinal.shape
# Out:
# (2580, 80)

# %%
ordinal.head(3)
# Out:
#    MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0         6.0       5.0     1.0    1.0       3.0          3.0        0.0
# 1         0.0       5.0     1.0    1.0       3.0          3.0        0.0
# 2         6.0       1.0     1.0    1.0       3.0          3.0        0.0
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0        0.0        0.0          21.0         2.0         2.0       0.0
# 1        4.0        0.0           7.0         2.0         2.0       4.0
# 2        4.0        0.0          11.0         2.0         2.0       0.0
#
#    HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0         2.0        1.0       0.0         13.0         14.0         2.0
# 1         2.0        1.0       0.0          6.0          6.0         1.0
# 2         2.0        3.0       0.0          8.0          8.0         2.0
#
#    ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 0        3.0        4.0         1.0       5.0       5.0           3.0
# 1        2.0        4.0         1.0       2.0       5.0           2.0
# 2        2.0        4.0         0.0       5.0       5.0           3.0
#
#    BsmtFinType1  BsmtFinType2  Heating  HeatingQC  CentralAir  Electrical  \
# 0           5.0           6.0      1.0        4.0         1.0         4.0
# 1           2.0           0.0      1.0        4.0         1.0         4.0
# 2           0.0           6.0      1.0        0.0         1.0         4.0
#
#    KitchenQual  Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 0          4.0         6.0          2.0         5.0           3.0         5.0
# 1          2.0         6.0          3.0         1.0           0.0         5.0
# 2          2.0         6.0          3.0         5.0           3.0         5.0
#
#    GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  MoSold  YrSold  \
# 0         5.0         2.0     3.0    4.0          1.0     5.0     4.0
# 1         5.0         2.0     3.0    4.0          1.0     4.0     3.0
# 2         4.0         0.0     3.0    4.0          1.0     2.0     1.0
#
#    SaleType  SaleCondition  GrLivArea  SalePrice  LotFrontage  LotArea  \
# 0       9.0            4.0        856     126000    68.516053     7890
# 1       9.0            4.0       1049     139500    42.000000     4235
# 2       9.0            4.0       1001     124900    60.000000     6060
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0            6            6       1939          1950         0.0       238.0
# 1            5            5       1984          1984       149.0       552.0
# 2            5            9       1930          2007         0.0       737.0
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0         0.0      618.0        856.0       856         0             0
# 1       393.0      104.0       1049.0      1049         0             0
# 2         0.0      100.0        837.0      1001         0             0
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         1         0             2             1
# 1           1.0           0.0         2         0             2             1
# 2           0.0           0.0         1         0             2             1
#
#    TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  \
# 0             4           1       1939.0         2.0       399.0           0
# 1             5           0       1984.0         1.0       266.0           0
# 2             5           0       1930.0         1.0       216.0         154
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal
# 0            0              0          0          166         0        0
# 1          105              0          0            0         0        0
# 2            0             42         86            0         0        0

# %%
X = ordinal.drop(['SalePrice'], axis=1)
y = ordinal.SalePrice

# %%
GB = GradientBoostingRegressor()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25, random_state = 1)
    
GB.fit(X_train, Y_train)
y_pred = GB.predict(X_test)

GB_Score = r2_score(Y_test, y_pred)
GB_Score
# Out:
# 0.9181575776177098

# %%
feature_importance = GB.feature_importances_
sorted_idx = np.argsort(feature_importance)

fig = plt.figure(figsize=(12, 25))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X_test.columns)[sorted_idx])
plt.title('Feature Importance');

# %%
X_cols = ordinal.drop(['SalePrice'], axis=1).columns
sorted_importance = sorted(zip(X_cols, GB.feature_importances_), key=lambda t:t[1], reverse=True)
sorted_importance
# Out:
# [('OverallQual', 0.49154026228776526),
#  ('GrLivArea', 0.15610270879743673),
#  ('TotalBsmtSF', 0.05481387660637798),
#  ('YearBuilt', 0.03771209251661736),
#  ('1stFlrSF', 0.03348720580990364),
#  ('BsmtFinSF1', 0.029812317291613905),
#  ('GarageArea', 0.02174836032921921),
#  ('2ndFlrSF', 0.019981231661670776),
#  ('BsmtQual', 0.01772054042197984),
#  ('GarageCars', 0.016634390155551328),
#  ('Fireplaces', 0.015992681570600145),
#  ('LotArea', 0.014960877146098783),
#  ('GarageType', 0.011974999847929883),
#  ('YearRemodAdd', 0.010540857581223256),
#  ('KitchenQual', 0.008876489995854636),
#  ('MasVnrArea', 0.006802994436816388),
#  ('OverallCond', 0.005631654047001441),
#  ('BsmtFinType1', 0.005592786178841885),
#  ('ExterQual', 0.004700047827116035),
#  ('Neighborhood', 0.004647035271964827),
#  ('BsmtExposure', 0.003885853462326237),
#  ('FullBath', 0.003800563740022858),
#  ('CentralAir', 0.0036326329664644634),
#  ('BsmtFullBath', 0.0026304404440615414),
#  ('SaleCondition', 0.00254277189653456),
#  ('MSZoning', 0.0018086555583346135),
#  ('HeatingQC', 0.0015787446935764432),
#  ('Functional', 0.0011525270885264654),
#  ('LandContour', 0.0011152324759266825),
#  ('Condition1', 0.0009942691224718414),
#  ('OpenPorchSF', 0.0008475926505586315),
#  ('ScreenPorch', 0.0006965932471047061),
#  ('GarageYrBlt', 0.000671462181314286),
#  ('HalfBath', 0.0005747798882586164),
#  ('BsmtFinSF2', 0.0005300947623132388),
#  ('LotFrontage', 0.0004897861410023977),
#  ('BsmtUnfSF', 0.00036313003753819784),
#  ('WoodDeckSF', 0.0003624185579750515),
#  ('Exterior1st', 0.0002955405387093536),
#  ('MoSold', 0.00026330743280807254),
#  ('MSSubClass', 0.00022639725912058922),
#  ('MasVnrType', 0.00021527308398303587),
#  ('FireplaceQu', 0.00021027819349449974),
#  ('GarageCond', 0.00019675215729703132),
#  ('YrSold', 0.00018583684654010124),
#  ('Condition2', 0.0001803805316528102),
#  ('BedroomAbvGr', 0.0001514701546772772),
#  ('BsmtFinType2', 0.00015146750286357513),
#  ('PavedDrive', 0.00010934649755466646),
#  ('RoofMatl', 0.00010594250099219461),
#  ('Exterior2nd', 0.00010336170260155593),
#  ('Heating', 9.781958834123515e-05),
#  ('EnclosedPorch', 9.190854826115704e-05),
#  ('TotRmsAbvGrd', 8.125152281540722e-05),
#  ('Foundation', 7.574231147342256e-05),
#  ('BldgType', 6.780766046723685e-05),
#  ('LotConfig', 6.774899883207185e-05),
#  ('ExterCond', 6.277507239863287e-05),
#  ('Fence', 5.398353776927459e-05),
#  ('RoofStyle', 2.7794244640043783e-05),
#  ('LowQualFinSF', 2.6855416812451896e-05),
#  ('Street', 0.0),
#  ('Alley', 0.0),
#  ('LotShape', 0.0),
#  ('Utilities', 0.0),
#  ('LandSlope', 0.0),
#  ('HouseStyle', 0.0),
#  ('BsmtCond', 0.0),
#  ('Electrical', 0.0),
#  ('GarageFinish', 0.0),
#  ('GarageQual', 0.0),
#  ('PoolQC', 0.0),
#  ('MiscFeature', 0.0),
#  ('SaleType', 0.0),
#  ('BsmtHalfBath', 0.0),
#  ('KitchenAbvGr', 0.0),
#  ('3SsnPorch', 0.0),
#  ('PoolArea', 0.0),
#  ('MiscVal', 0.0)]
