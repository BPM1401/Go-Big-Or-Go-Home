# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", 300)

# %%
check = pd.read_csv('Ordinal+Ridge_Drop1.csv')

# %%
check.shape
# Out:
# (2579, 84)

# %%
check[check.GrLivArea > 4000]
# Out:
#       Unnamed: 0  MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  \
# 1006        1007        10.0       5.0     1.0    1.0       0.0          3.0
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 1006        0.0        0.0        0.0          18.0         2.0         2.0
#
#       BldgType  HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 1006       0.0         5.0        1.0       6.0          6.0          6.0
#
#       MasVnrType  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 1006         1.0        0.0        4.0         2.0       0.0       5.0
#
#       BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  HeatingQC  \
# 1006           1.0           2.0           6.0      1.0        0.0
#
#       CentralAir  Electrical  KitchenQual  Functional  FireplaceQu  \
# 1006         1.0         4.0          0.0         6.0          0.0
#
#       GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  \
# ...

# %%
check2 = pd.read_csv('Ordinal+Ridge.csv')
check2.shape
# Out:
# (2580, 84)

# %%
check2[check2.GrLivArea > 4000]
# Out:
#       Unnamed: 0  MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  \
# 309          309        10.0       5.0     1.0    1.0       0.0          0.0
# 1007        1007        10.0       5.0     1.0    1.0       0.0          3.0
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 309         0.0        4.0        0.0           7.0         4.0         4.0
# 1007        0.0        0.0        0.0          18.0         2.0         2.0
#
#       BldgType  HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 309        0.0         5.0        3.0       0.0          5.0          5.0
# 1007       0.0         5.0        1.0       6.0          6.0          6.0
#
#       MasVnrType  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 309          3.0        0.0        4.0         2.0       0.0       5.0
# 1007         1.0        0.0        4.0         2.0       0.0       5.0
#
# ...

# %%
check2 = check2.drop(check2.iloc[309].name)
check2.shape
# Out:
# (2579, 84)

# %%
check2[check2.GrLivArea > 4000]
# Out:
#       Unnamed: 0  MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  \
# 1007        1007        10.0       5.0     1.0    1.0       0.0          3.0
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 1007        0.0        0.0        0.0          18.0         2.0         2.0
#
#       BldgType  HouseStyle  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 1007       0.0         5.0        1.0       6.0          6.0          6.0
#
#       MasVnrType  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 1007         1.0        0.0        4.0         2.0       0.0       5.0
#
#       BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  HeatingQC  \
# 1007           1.0           2.0           6.0      1.0        0.0
#
#       CentralAir  Electrical  KitchenQual  Functional  FireplaceQu  \
# 1007         1.0         4.0          0.0         6.0          0.0
#
#       GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  \
# ...

# %%
check['diff'] = abs(check.SalePrice - check.Ridge)
check['diff']
# Out:
# 0        8737.947886
# 1       20214.286445
# 2        6346.948573
# 3        8907.996319
# 4       16451.113532
#             ...
# 2574     4846.003084
# 2575     1604.930234
# 2576    20233.826674
# 2577     6588.486247
# 2578     1639.835418
# Name: diff, Length: 2579, dtype: float64

# %%
np.sum(check['diff'])
# Out:
# 31309853.31730637

# %%
check2['diff'] = abs(check2.SalePrice - check2.Ridge)
check2['diff']
# Out:
# 0        6304.357278
# 1       21357.671653
# 2        4898.673755
# 3        7376.768101
# 4       16276.872944
#             ...
# 2575     3639.950304
# 2576     1546.414426
# 2577    20687.514994
# 2578     6539.070581
# 2579     1858.963881
# Name: diff, Length: 2579, dtype: float64

# %%
np.sum(check2['diff'])
# Out:
# 31514611.699744865
